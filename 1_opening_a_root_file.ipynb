# %% [markdown]
# ## Introduction
#
# In this notebook we are going to open a root file and take a look at some of the data that is stored. This is a file with real LHC data.

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import uproot
import h5py
import yaml
import pickle 
import mplhep as hep
import awkward as ak
import sklearn.metrics as metrics

plt.rcParams['figure.dpi'] = 100
# Out:
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
filename = "/uscms/home/jpearkes/eos/forAda/scouting_nano.root" # originally from root://hip-cms-se.csc.fi//store/user/pinkaew/scouting_nano_prod_golden/ScoutingPFRun3/crab_ScoutingPFRun3_Run2024D-v1_380385-380470_Golden/240517_205837/0000/scouting_nano_399.root

file = uproot.open(filename)

# %%
# Take a look at the file contents 
file.keys()
# Out:
# ['Events;1', 'LuminosityBlocks;1', 'Runs;1', 'MetaData;1', 'ParameterSets;1']

# %%
# The important stuff is stored in "Events"
file["Events"]
# Out:
# <TTree 'Events' (1510 branches) at 0x7f40a5b3ff70>

# %%
file["Events"].keys()
# Out:
# ['run',
#  'luminosityBlock',
#  'event',
#  'bunchCrossing',
#  'orbitNumber',
#  'nScoutingJet',
#  'ScoutingJet_nConstituents',
#  'ScoutingJet_nCh',
#  'ScoutingJet_nElectrons',
#  'ScoutingJet_nMuons',
#  'ScoutingJet_nNh',
#  'ScoutingJet_nPhotons',
#  'ScoutingJet_area',
#  'ScoutingJet_chEmEF',
#  'ScoutingJet_chHEF',
#  'ScoutingJet_eta',
#  'ScoutingJet_mass',
#  'ScoutingJet_muEF',
#  'ScoutingJet_neEmEF',
#  'ScoutingJet_neHEF',
#  'ScoutingJet_phi',
#  'ScoutingJet_pt',
#  'ScoutingJet_particleNet_prob_b',
#  'ScoutingJet_particleNet_prob_bb',
#  'ScoutingJet_particleNet_prob_c',
#  'ScoutingJet_particleNet_prob_cc',
#  'ScoutingJet_particleNet_prob_g',
#  'ScoutingJet_particleNet_prob_undef',
#  'ScoutingJet_particlenet_prob_uds',
#  'nScoutingFatJet',
#  'ScoutingFatJet_nConstituents',
#  'ScoutingFatJet_nCh',
#  'ScoutingFatJet_nElectrons',
#  'ScoutingFatJet_nMuons',
#  'ScoutingFatJet_nNh',
#  'ScoutingFatJet_nPhotons',
#  'ScoutingFatJet_area',
#  'ScoutingFatJet_chEmEF',
#  'ScoutingFatJet_chHEF',
#  'ScoutingFatJet_eta',
#  'ScoutingFatJet_mass',
#  'ScoutingFatJet_muEF',
#  'ScoutingFatJet_neEmEF',
#  'ScoutingFatJet_neHEF',
#  'ScoutingFatJet_phi',
#  'ScoutingFatJet_pt',
#  'ScoutingFatJet_msoftdrop',
#  'ScoutingFatJet_n2b1',
#  'ScoutingFatJet_n3b1',
#  'ScoutingFatJet_particleNet_mass',
#  'ScoutingFatJet_particleNet_prob_Hbb',
#  'ScoutingFatJet_particleNet_prob_Hcc',
#  'ScoutingFatJet_particleNet_prob_Hqq',
#  'ScoutingFatJet_particleNet_prob_QCD',
#  'ScoutingFatJet_tau1',
#  'ScoutingFatJet_tau2',
#  'ScoutingFatJet_tau3',
#  'ScoutingFatJet_tau4',
#  'nScoutingMuonNoVtxDisplacedVertex',
#  'ScoutingMuonNoVtxDisplacedVertex_isValidVtx',
#  'ScoutingMuonNoVtxDisplacedVertex_ndof',
#  'ScoutingMuonNoVtxDisplacedVertex_tracksSize',
#  'ScoutingMuonNoVtxDisplacedVertex_chi2',
#  'ScoutingMuonNoVtxDisplacedVertex_x',
#  'ScoutingMuonNoVtxDisplacedVertex_xError',
#  'ScoutingMuonNoVtxDisplacedVertex_y',
#  'ScoutingMuonNoVtxDisplacedVertex_yError',
#  'ScoutingMuonNoVtxDisplacedVertex_z',
#  'ScoutingMuonNoVtxDisplacedVertex_zError',
#  'nScoutingMuonVtxDisplacedVertex',
#  'ScoutingMuonVtxDisplacedVertex_isValidVtx',
#  'ScoutingMuonVtxDisplacedVertex_ndof',
#  'ScoutingMuonVtxDisplacedVertex_tracksSize',
#  'ScoutingMuonVtxDisplacedVertex_chi2',
#  'ScoutingMuonVtxDisplacedVertex_x',
#  'ScoutingMuonVtxDisplacedVertex_xError',
#  'ScoutingMuonVtxDisplacedVertex_y',
#  'ScoutingMuonVtxDisplacedVertex_yError',
#  'ScoutingMuonVtxDisplacedVertex_z',
#  'ScoutingMuonVtxDisplacedVertex_zError',
#  'nScoutingElectron',
#  'ScoutingElectron_missingHits',
#  'ScoutingElectron_seedId',
#  'ScoutingElectron_dEtaIn',
#  'ScoutingElectron_dPhiIn',
#  'ScoutingElectron_ecalIso',
#  'ScoutingElectron_eta',
#  'ScoutingElectron_hOverE',
#  'ScoutingElectron_hcalIso',
#  'ScoutingElectron_m',
#  'ScoutingElectron_ooEMOop',
#  'ScoutingElectron_phi',
#  'ScoutingElectron_pt',
#  'ScoutingElectron_r9',
#  'ScoutingElectron_sMaj',
#  'ScoutingElectron_sMin',
#  'ScoutingElectron_sigmaIetaIeta',
#  'ScoutingElectron_trackIso',
#  'nL1EG',
#  'L1EG_hwIso',
#  'L1EG_bx',
#  'L1EG_eta',
#  'L1EG_phi',
#  'L1EG_pt',
#  'nL1EtSum',
#  'L1EtSum_bx',
#  'L1EtSum_etSumType',
#  'L1EtSum_phi',
#  'L1EtSum_pt',
#  'nL1Jet',
#  'L1Jet_bx',
#  'L1Jet_eta',
#  'L1Jet_phi',
#  'L1Jet_pt',
#  'nL1Mu',
#  'L1Mu_hwCharge',
#  'L1Mu_hwDXY',
#  'L1Mu_bx',
#  'L1Mu_hwQual',
#  'L1Mu_eta',
#  'L1Mu_etaAtVtx',
#  'L1Mu_phi',
#  'L1Mu_phiAtVtx',
#  'L1Mu_pt',
#  'L1Mu_ptUnconstrained',
#  'nL1Tau',
#  'L1Tau_hwIso',
#  'L1Tau_bx',
#  'L1Tau_eta',
#  'L1Tau_phi',
#  'L1Tau_pt',
#  'ScoutingMET_phi',
#  'ScoutingMET_pt',
#  'nScoutingMuonNoVtx',
#  'ScoutingMuonNoVtx_charge',
#  'ScoutingMuonNoVtx_nPixelLayersWithMeasurement',
#  'ScoutingMuonNoVtx_nRecoMuonChambers',
#  'ScoutingMuonNoVtx_nRecoMuonChambersCSCorDT',
#  'ScoutingMuonNoVtx_nRecoMuonExpectedMatchedStations',
#  'ScoutingMuonNoVtx_nRecoMuonMatchedRPCLayers',
#  'ScoutingMuonNoVtx_nRecoMuonMatchedStations',
#  'ScoutingMuonNoVtx_nRecoMuonMatches',
#  'ScoutingMuonNoVtx_nStandAloneMuonMatchedStations',
#  'ScoutingMuonNoVtx_nTrackerLayersWithMeasurement',
#  'ScoutingMuonNoVtx_nValidPixelHits',
#  'ScoutingMuonNoVtx_nValidRecoMuonHits',
#  'ScoutingMuonNoVtx_nValidStandAloneMuonHits',
#  'ScoutingMuonNoVtx_nValidStripHits',
#  'ScoutingMuonNoVtx_recoMuonRPClayerMask',
#  'ScoutingMuonNoVtx_recoMuonStationMask',
#  'ScoutingMuonNoVtx_type',
#  'ScoutingMuonNoVtx_ecalIso',
#  'ScoutingMuonNoVtx_eta',
#  'ScoutingMuonNoVtx_hcalIso',
#  'ScoutingMuonNoVtx_m',
#  'ScoutingMuonNoVtx_normchi2',
#  'ScoutingMuonNoVtx_phi',
#  'ScoutingMuonNoVtx_pt',
#  'ScoutingMuonNoVtx_trackIso',
#  'ScoutingMuonNoVtx_trk_chi2',
#  'ScoutingMuonNoVtx_trk_dsz',
#  'ScoutingMuonNoVtx_trk_dszError',
#  'ScoutingMuonNoVtx_trk_dxy',
#  'ScoutingMuonNoVtx_trk_dxyError',
#  'ScoutingMuonNoVtx_trk_dxy_dsz_cov',
#  'ScoutingMuonNoVtx_trk_dz',
#  'ScoutingMuonNoVtx_trk_dzError',
#  'ScoutingMuonNoVtx_trk_eta',
#  'ScoutingMuonNoVtx_trk_lambda',
#  'ScoutingMuonNoVtx_trk_lambdaError',
#  'ScoutingMuonNoVtx_trk_lambda_dsz_cov',
#  'ScoutingMuonNoVtx_trk_lambda_dxy_cov',
#  'ScoutingMuonNoVtx_trk_lambda_phi_cov',
#  'ScoutingMuonNoVtx_trk_ndof',
#  'ScoutingMuonNoVtx_trk_phi',
#  'ScoutingMuonNoVtx_trk_phiError',
#  'ScoutingMuonNoVtx_trk_phi_dsz_cov',
#  'ScoutingMuonNoVtx_trk_phi_dxy_cov',
#  'ScoutingMuonNoVtx_trk_pt',
#  'ScoutingMuonNoVtx_trk_qoverp',
#  'ScoutingMuonNoVtx_trk_qoverpError',
#  'ScoutingMuonNoVtx_trk_qoverp_dsz_cov',
#  'ScoutingMuonNoVtx_trk_qoverp_dxy_cov',
#  'ScoutingMuonNoVtx_trk_qoverp_lambda_cov',
#  'ScoutingMuonNoVtx_trk_qoverp_phi_cov',
#  'ScoutingMuonNoVtx_trk_vx',
#  'ScoutingMuonNoVtx_trk_vy',
#  'ScoutingMuonNoVtx_trk_vz',
#  'nScoutingMuonVtx',
#  'ScoutingMuonVtx_charge',
#  'ScoutingMuonVtx_nPixelLayersWithMeasurement',
#  'ScoutingMuonVtx_nRecoMuonChambers',
#  'ScoutingMuonVtx_nRecoMuonChambersCSCorDT',
#  'ScoutingMuonVtx_nRecoMuonExpectedMatchedStations',
#  'ScoutingMuonVtx_nRecoMuonMatchedRPCLayers',
#  'ScoutingMuonVtx_nRecoMuonMatchedStations',
#  'ScoutingMuonVtx_nRecoMuonMatches',
#  'ScoutingMuonVtx_nStandAloneMuonMatchedStations',
#  'ScoutingMuonVtx_nTrackerLayersWithMeasurement',
#  'ScoutingMuonVtx_nValidPixelHits',
#  'ScoutingMuonVtx_nValidRecoMuonHits',
#  'ScoutingMuonVtx_nValidStandAloneMuonHits',
#  'ScoutingMuonVtx_nValidStripHits',
#  'ScoutingMuonVtx_recoMuonRPClayerMask',
#  'ScoutingMuonVtx_recoMuonStationMask',
#  'ScoutingMuonVtx_type',
#  'ScoutingMuonVtx_ecalIso',
#  'ScoutingMuonVtx_eta',
#  'ScoutingMuonVtx_hcalIso',
#  'ScoutingMuonVtx_m',
#  'ScoutingMuonVtx_normchi2',
#  'ScoutingMuonVtx_phi',
#  'ScoutingMuonVtx_pt',
#  'ScoutingMuonVtx_trackIso',
#  'ScoutingMuonVtx_trk_chi2',
#  'ScoutingMuonVtx_trk_dsz',
#  'ScoutingMuonVtx_trk_dszError',
#  'ScoutingMuonVtx_trk_dxy',
#  'ScoutingMuonVtx_trk_dxyError',
#  'ScoutingMuonVtx_trk_dxy_dsz_cov',
#  'ScoutingMuonVtx_trk_dz',
#  'ScoutingMuonVtx_trk_dzError',
#  'ScoutingMuonVtx_trk_eta',
#  'ScoutingMuonVtx_trk_lambda',
#  'ScoutingMuonVtx_trk_lambdaError',
#  'ScoutingMuonVtx_trk_lambda_dsz_cov',
#  'ScoutingMuonVtx_trk_lambda_dxy_cov',
#  'ScoutingMuonVtx_trk_lambda_phi_cov',
#  'ScoutingMuonVtx_trk_ndof',
#  'ScoutingMuonVtx_trk_phi',
#  'ScoutingMuonVtx_trk_phiError',
#  'ScoutingMuonVtx_trk_phi_dsz_cov',
#  'ScoutingMuonVtx_trk_phi_dxy_cov',
#  'ScoutingMuonVtx_trk_pt',
#  'ScoutingMuonVtx_trk_qoverp',
#  'ScoutingMuonVtx_trk_qoverpError',
#  'ScoutingMuonVtx_trk_qoverp_dsz_cov',
#  'ScoutingMuonVtx_trk_qoverp_dxy_cov',
#  'ScoutingMuonVtx_trk_qoverp_lambda_cov',
#  'ScoutingMuonVtx_trk_qoverp_phi_cov',
#  'ScoutingMuonVtx_trk_vx',
#  'ScoutingMuonVtx_trk_vy',
#  'ScoutingMuonVtx_trk_vz',
#  'nScoutingParticle',
#  'ScoutingParticle_charge',
#  'ScoutingParticle_pdgId',
#  'ScoutingParticle_trkLostInnerHits',
#  'ScoutingParticle_trkQuality',
#  'ScoutingParticle_vertexIndex',
#  'ScoutingParticle_eta',
#  'ScoutingParticle_mass',
#  'ScoutingParticle_phi',
#  'ScoutingParticle_pt',
#  'ScoutingParticle_trkDxy',
#  'ScoutingParticle_trkDxysig',
#  'ScoutingParticle_trkDz',
#  'ScoutingParticle_trkDzsig',
#  'ScoutingParticle_trkEta',
#  'ScoutingParticle_trkNormchi2',
#  'ScoutingParticle_trkPhi',
#  'ScoutingParticle_trkPt',
#  'nScoutingPhoton',
#  'ScoutingPhoton_seedId',
#  'ScoutingPhoton_ecalIso',
#  'ScoutingPhoton_eta',
#  'ScoutingPhoton_hOverE',
#  'ScoutingPhoton_hcalIso',
#  'ScoutingPhoton_m',
#  'ScoutingPhoton_phi',
#  'ScoutingPhoton_pt',
#  'ScoutingPhoton_r9',
#  'ScoutingPhoton_sMaj',
#  'ScoutingPhoton_sMin',
#  'ScoutingPhoton_sigmaIetaIeta',
#  'nScoutingPrimaryVertex',
#  'ScoutingPrimaryVertex_isValidVtx',
#  'ScoutingPrimaryVertex_ndof',
#  'ScoutingPrimaryVertex_tracksSize',
#  'ScoutingPrimaryVertex_chi2',
#  'ScoutingPrimaryVertex_x',
#  'ScoutingPrimaryVertex_xError',
#  'ScoutingPrimaryVertex_y',
#  'ScoutingPrimaryVertex_yError',
#  'ScoutingPrimaryVertex_z',
#  'ScoutingPrimaryVertex_zError',
#  'ScoutingRho',
#  'nScoutingTrack',
#  'ScoutingTrack_charge',
#  'ScoutingTrack_nTrackerLayersWithMeasurement',
#  'ScoutingTrack_nValidPixelHits',
#  'ScoutingTrack_nValidStripHits',
#  'ScoutingTrack_vtxInd',
#  'ScoutingTrack__lambda',
#  'ScoutingTrack_chi2',
#  'ScoutingTrack_dsz',
#  'ScoutingTrack_dszError',
#  'ScoutingTrack_dxy',
#  'ScoutingTrack_dxyError',
#  'ScoutingTrack_dxy_dsz_cov',
#  'ScoutingTrack_dz',
#  'ScoutingTrack_dzError',
#  'ScoutingTrack_eta',
#  'ScoutingTrack_lambdaError',
#  'ScoutingTrack_lambda_dsz_cov',
#  'ScoutingTrack_lambda_dxy_cov',
#  'ScoutingTrack_lambda_phi_cov',
#  'ScoutingTrack_ndof',
#  'ScoutingTrack_phi',
#  'ScoutingTrack_phiError',
#  'ScoutingTrack_phi_dsz_cov',
#  'ScoutingTrack_phi_dxy_cov',
#  'ScoutingTrack_pt',
#  'ScoutingTrack_qoverp',
#  'ScoutingTrack_qoverpError',
#  'ScoutingTrack_qoverp_dsz_cov',
#  'ScoutingTrack_qoverp_dxy_cov',
#  'ScoutingTrack_qoverp_lambda_cov',
#  'ScoutingTrack_qoverp_phi_cov',
#  'ScoutingTrack_vx',
#  'ScoutingTrack_vy',
#  'ScoutingTrack_vz',
#  'L1_AlwaysTrue',
#  'L1_BPTX_AND_Ref1_VME',
#  'L1_BPTX_AND_Ref3_VME',
#  'L1_BPTX_AND_Ref4_VME',
#  'L1_BPTX_BeamGas_B1_VME',
#  'L1_BPTX_BeamGas_B2_VME',
#  'L1_BPTX_BeamGas_Ref1_VME',
#  'L1_BPTX_BeamGas_Ref2_VME',
#  'L1_BPTX_NotOR_VME',
#  'L1_BPTX_OR_Ref3_VME',
#  'L1_BPTX_OR_Ref4_VME',
#  'L1_BPTX_RefAND_VME',
#  'L1_BptxMinus',
#  'L1_BptxMinus_NotBptxPlus',
#  'L1_BptxOR',
#  'L1_BptxPlus',
#  'L1_BptxPlus_NotBptxMinus',
#  'L1_BptxXOR',
#  'L1_Centrality_0_0p5_BptxAND',
#  'L1_Centrality_0_1_BptxAND',
#  'L1_Centrality_30_100_MinimumBiasHF1_AND_BptxAND',
#  'L1_Centrality_30_40_BptxAND',
#  'L1_Centrality_30_50_BptxAND',
#  'L1_Centrality_40_50_BptxAND',
#  'L1_Centrality_50_100_MinimumBiasHF1_AND_BptxAND',
#  'L1_Centrality_50_65_BptxAND',
#  'L1_Centrality_65_80_BptxAND',
#  'L1_Centrality_80_100_BptxAND',
#  'L1_Centrality_Saturation_BptxAND',
#  'L1_DoubleEG10_BptxAND',
#  'L1_DoubleEG1_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleEG2_BptxAND',
#  'L1_DoubleEG2_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleEG3_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleEG5_BptxAND',
#  'L1_DoubleEG5_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleEG8_BptxAND',
#  'L1_DoubleEG_22_10_er2p5',
#  'L1_DoubleEG_25_12_er2p5',
#  'L1_DoubleEG_25_14_er2p5',
#  'L1_DoubleJet100er2p5',
#  'L1_DoubleJet120er2p5',
#  'L1_DoubleJet40er2p5',
#  'L1_DoubleJet_12_8_ZDC1n_AsymXOR_BptxAND',
#  'L1_DoubleJet_12_8_ZDC1n_XOR_BptxAND',
#  'L1_DoubleJet_16_12_ZDC1n_AsymXOR_BptxAND',
#  'L1_DoubleJet_16_12_ZDC1n_XOR_BptxAND',
#  'L1_DoubleJet_24_16_ZDC1n_AsymXOR_BptxAND',
#  'L1_DoubleJet_24_16_ZDC1n_XOR_BptxAND',
#  'L1_DoubleJet_8_8_ZDC1n_AsymXOR_BptxAND',
#  'L1_DoubleJet_8_8_ZDC1n_XOR_BptxAND',
#  'L1_DoubleMu0',
#  'L1_DoubleMu0_BptxAND',
#  'L1_DoubleMu0_MaxDr3p5M0to7_BptxAND',
#  'L1_DoubleMu0_MaxDr3p5_BptxAND',
#  'L1_DoubleMu0_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleMu0_SQ',
#  'L1_DoubleMu0_SQ_OS',
#  'L1_DoubleMu10_BptxAND',
#  'L1_DoubleMuCosmic_BptxAND',
#  'L1_DoubleMuCosmic_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleMuOpen_BptxAND',
#  'L1_DoubleMuOpen_Centrality_30_100_BptxAND',
#  'L1_DoubleMuOpen_Centrality_40_100_BptxAND',
#  'L1_DoubleMuOpen_Centrality_50_100_BptxAND',
#  'L1_DoubleMuOpen_MaxDr3p5M0to7_BptxAND',
#  'L1_DoubleMuOpen_MaxDr3p5_BptxAND',
#  'L1_DoubleMuOpen_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_DoubleMuOpen_OS_BptxAND',
#  'L1_DoubleMuOpen_SS_BptxAND',
#  'L1_DoubleMuSQ_BptxAND',
#  'L1_DoubleMuSQ_MaxDr3p5M0to7_BptxAND',
#  'L1_DoubleMuSQ_MaxDr3p5_BptxAND',
#  'L1_DoubleMu_12_5',
#  'L1_DoubleMu_15_7',
#  'L1_ETMHF100',
#  'L1_ETT2000',
#  'L1_FirstBunchAfterTrain',
#  'L1_FirstBunchBeforeTrain',
#  'L1_FirstBunchInTrain',
#  'L1_FirstCollisionInOrbit',
#  'L1_FirstCollisionInOrbit_Centrality30_100_BptxAND',
#  'L1_FirstCollisionInOrbit_Centrality50_100_BptxAND',
#  'L1_FirstCollisionInTrain',
#  'L1_HCAL_LaserMon_Trig',
#  'L1_HCAL_LaserMon_Veto',
#  'L1_HTT120er',
#  'L1_HTT160er',
#  'L1_HTT200er',
#  'L1_HTT255er',
#  'L1_HTT280er',
#  'L1_HTT320er',
#  'L1_HTT360er',
#  'L1_HTT400er',
#  'L1_HTT450er',
#  'L1_IsolatedBunch',
#  'L1_LastBunchInTrain',
#  'L1_LastCollisionInTrain',
#  'L1_MinimumBiasHF1_AND_BptxAND',
#  'L1_MinimumBiasHF1_OR_BptxAND',
#  'L1_MinimumBiasHF2_AND_BptxAND',
#  'L1_MinimumBiasHF2_OR_BptxAND',
#  'L1_NotBptxOR',
#  'L1_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_QuadJet60er2p5',
#  'L1_SecondBunchInTrain',
#  'L1_SecondLastBunchInTrain',
#  'L1_SingleEG10er2p5',
#  'L1_SingleEG12_BptxAND',
#  'L1_SingleEG15_BptxAND',
#  'L1_SingleEG15_Centrality_30_100_BptxAND',
#  'L1_SingleEG15er2p5',
#  'L1_SingleEG21_BptxAND',
#  'L1_SingleEG21_Centrality_30_100_BptxAND',
#  'L1_SingleEG26er2p5',
#  'L1_SingleEG2_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG2_ZDC1n_Bkp1_OR_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG2_ZDC1n_Bkp2_OR_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG2_ZDC1n_Bkp3_OR_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG2_ZDC1n_OR_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG3',
#  'L1_SingleEG30_BptxAND',
#  'L1_SingleEG34er2p5',
#  'L1_SingleEG36er2p5',
#  'L1_SingleEG38er2p5',
#  'L1_SingleEG3_BptxAND',
#  'L1_SingleEG3_Centrality_30_100_BptxAND',
#  'L1_SingleEG3_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG3_NotMinimumBiasHF2_OR_BptxAND',
#  'L1_SingleEG40er2p5',
#  'L1_SingleEG42er2p5',
#  'L1_SingleEG45er2p5',
#  'L1_SingleEG4_BptxAND',
#  'L1_SingleEG4_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG4_NotMinimumBiasHF2_OR_BptxAND',
#  'L1_SingleEG5',
#  'L1_SingleEG50',
#  'L1_SingleEG5_BptxAND',
#  'L1_SingleEG5_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleEG60',
#  'L1_SingleEG7_BptxAND',
#  'L1_SingleEG7_Centrality_30_100_BptxAND',
#  'L1_SingleEG8er2p5',
#  'L1_SingleIsoEG12_BptxAND',
#  'L1_SingleIsoEG15_BptxAND',
#  'L1_SingleIsoEG21_BptxAND',
#  'L1_SingleIsoEG24er2p1',
#  'L1_SingleIsoEG26er2p1',
#  'L1_SingleIsoEG26er2p5',
#  'L1_SingleIsoEG28er2p1',
#  'L1_SingleIsoEG28er2p5',
#  'L1_SingleIsoEG30er2p1',
#  'L1_SingleIsoEG30er2p5',
#  'L1_SingleIsoEG32er2p1',
#  'L1_SingleIsoEG32er2p5',
#  'L1_SingleIsoEG34er2p5',
#  'L1_SingleJet10erHE',
#  'L1_SingleJet120',
#  'L1_SingleJet120_FWD3p0',
#  'L1_SingleJet120er2p5',
#  'L1_SingleJet12_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet12_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet12_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet12_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet12_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet12erHE',
#  'L1_SingleJet140er2p5',
#  'L1_SingleJet160er2p5',
#  'L1_SingleJet16_BptxAND',
#  'L1_SingleJet16_Centrality_30_100_BptxAND',
#  'L1_SingleJet16_Centrality_50_100_BptxAND',
#  'L1_SingleJet16_FWD_BptxAND',
#  'L1_SingleJet16_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet16_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet16_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet16_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet16_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet180',
#  'L1_SingleJet200',
#  'L1_SingleJet20_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet20_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet20_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet20_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet20_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet24_BptxAND',
#  'L1_SingleJet24_Centrality_30_100_BptxAND',
#  'L1_SingleJet24_Centrality_50_100_BptxAND',
#  'L1_SingleJet24_ETM10_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_ETM10_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_ETM15_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_ETM15_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_ETM30_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_ETM30_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_ETM50_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_ETM50_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_HTM10_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_HTM10_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_HTM15_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_HTM15_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_HTM30_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_HTM30_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_HTM50_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_HTM50_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet24_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet24_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet24_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet24_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet28_BptxAND',
#  'L1_SingleJet28_Centrality_30_100_BptxAND',
#  'L1_SingleJet28_Centrality_50_100_BptxAND',
#  'L1_SingleJet28_DMeson_BptxAND',
#  'L1_SingleJet28_FWD_BptxAND',
#  'L1_SingleJet28_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet28_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet28_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet28_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet28_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet32_BptxAND',
#  'L1_SingleJet32_Centrality_30_100_BptxAND',
#  'L1_SingleJet32_Centrality_50_100_BptxAND',
#  'L1_SingleJet35',
#  'L1_SingleJet35_FWD3p0',
#  'L1_SingleJet35er2p5',
#  'L1_SingleJet36_BptxAND',
#  'L1_SingleJet36_Centrality_30_100_BptxAND',
#  'L1_SingleJet36_Centrality_50_100_BptxAND',
#  'L1_SingleJet36_FWD_BptxAND',
#  'L1_SingleJet40_BptxAND',
#  'L1_SingleJet40_Centrality_30_100_BptxAND',
#  'L1_SingleJet40_Centrality_50_100_BptxAND',
#  'L1_SingleJet44_BptxAND',
#  'L1_SingleJet44_Centrality_30_100_BptxAND',
#  'L1_SingleJet44_Centrality_50_100_BptxAND',
#  'L1_SingleJet44_DMeson_BptxAND',
#  'L1_SingleJet44_FWD_BptxAND',
#  'L1_SingleJet48_BptxAND',
#  'L1_SingleJet48_Centrality_30_100_BptxAND',
#  'L1_SingleJet48_Centrality_50_100_BptxAND',
#  'L1_SingleJet56_BptxAND',
#  'L1_SingleJet56_Centrality_30_100_BptxAND',
#  'L1_SingleJet56_Centrality_50_100_BptxAND',
#  'L1_SingleJet56_FWD_BptxAND',
#  'L1_SingleJet60',
#  'L1_SingleJet60_BptxAND',
#  'L1_SingleJet60_Centrality_30_100_BptxAND',
#  'L1_SingleJet60_Centrality_50_100_BptxAND',
#  'L1_SingleJet60_DMeson_BptxAND',
#  'L1_SingleJet64_BptxAND',
#  'L1_SingleJet64_Centrality_30_100_BptxAND',
#  'L1_SingleJet64_Centrality_50_100_BptxAND',
#  'L1_SingleJet64_FWD_BptxAND',
#  'L1_SingleJet72_BptxAND',
#  'L1_SingleJet80_BptxAND',
#  'L1_SingleJet8_BptxAND',
#  'L1_SingleJet8_Centrality_30_100_BptxAND',
#  'L1_SingleJet8_Centrality_50_100_BptxAND',
#  'L1_SingleJet8_FWD_BptxAND',
#  'L1_SingleJet8_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleJet8_ZDC1n_AsymXOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_AsymXOR_MidEta2p5_BptxAND',
#  'L1_SingleJet8_ZDC1n_AsymXOR_NotPreBptx_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp1_AsymXOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp1_XOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp2_AsymXOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp2_XOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp3_AsymXOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_Bkp3_XOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_XOR_BptxAND',
#  'L1_SingleJet8_ZDC1n_XOR_MidEta2p5_BptxAND',
#  'L1_SingleJet8_ZDC1n_XOR_NotPreBptx_BptxAND',
#  'L1_SingleJet8erHE',
#  'L1_SingleJet90',
#  'L1_SingleMu0_BMTF',
#  'L1_SingleMu0_BptxAND',
#  'L1_SingleMu0_DQ',
#  'L1_SingleMu0_EMTF',
#  'L1_SingleMu0_OMTF',
#  'L1_SingleMu12_SingleEG7_BptxAND',
#  'L1_SingleMu18',
#  'L1_SingleMu20',
#  'L1_SingleMu22',
#  'L1_SingleMu22_BMTF',
#  'L1_SingleMu22_EMTF',
#  'L1_SingleMu22_OMTF',
#  'L1_SingleMu25',
#  'L1_SingleMu3',
#  'L1_SingleMu3Open_BptxAND',
#  'L1_SingleMu3_BptxAND',
#  'L1_SingleMu3_SingleEG12_BptxAND',
#  'L1_SingleMu3_SingleEG20_BptxAND',
#  'L1_SingleMu3_SingleEG30_BptxAND',
#  'L1_SingleMu3_SingleJet28_MidEta2p7_BptxAND',
#  'L1_SingleMu3_SingleJet32_MidEta2p7_BptxAND',
#  'L1_SingleMu3_SingleJet40_MidEta2p7_BptxAND',
#  'L1_SingleMu5',
#  'L1_SingleMu5_BptxAND',
#  'L1_SingleMu5_SingleEG10_BptxAND',
#  'L1_SingleMu5_SingleEG12_BptxAND',
#  'L1_SingleMu5_SingleEG15_BptxAND',
#  'L1_SingleMu5_SingleEG20_BptxAND',
#  'L1_SingleMu7',
#  'L1_SingleMu7_BptxAND',
#  'L1_SingleMu7_SingleEG10_BptxAND',
#  'L1_SingleMu7_SingleEG12_BptxAND',
#  'L1_SingleMu7_SingleEG15_BptxAND',
#  'L1_SingleMu7_SingleEG7_BptxAND',
#  'L1_SingleMuCosmic_BptxAND',
#  'L1_SingleMuCosmic_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleMuCosmic_NotMinimumBiasHF2_OR_BptxAND',
#  'L1_SingleMuCosmics',
#  'L1_SingleMuCosmics_BMTF',
#  'L1_SingleMuCosmics_EMTF',
#  'L1_SingleMuCosmics_OMTF',
#  'L1_SingleMuOpen',
#  'L1_SingleMuOpen_BptxAND',
#  'L1_SingleMuOpen_NotBptxOR',
#  'L1_SingleMuOpen_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleMuOpen_NotMinimumBiasHF2_OR_BptxAND',
#  'L1_SingleMuOpen_OR_SingleMuCosmic_EMTF_BptxAND',
#  'L1_SingleMuOpen_OR_SingleMuCosmic_EMTF_NotMinimumBiasHF2_AND_BptxAND',
#  'L1_SingleMuOpen_OR_SingleMuCosmic_EMTF_NotMinimumBiasHF2_OR_BptxAND',
#  'L1_SingleMuOpen_SingleEG15_BptxAND',
#  'L1_SingleMuOpen_SingleJet28_MidEta2p7_BptxAND',
#  'L1_SingleMuOpen_SingleJet44_MidEta2p7_BptxAND',
#  'L1_SingleMuOpen_SingleJet56_MidEta2p7_BptxAND',
#  'L1_SingleMuOpen_SingleJet64_MidEta2p7_BptxAND',
#  'L1_SingleMuOpen_er1p1_NotBptxOR_3BX',
#  'L1_SingleMuOpen_er1p4_NotBptxOR_3BX',
#  'L1_SingleMuShower_Nominal',
#  'L1_SingleMuShower_Nominal_BptxAND',
#  'L1_SingleMuShower_Tight',
#  'L1_SingleMuShower_Tight_BptxAND',
#  'L1_TripleEG_18_17_8_er2p5',
#  'L1_TripleMu_5_3_3',
#  'L1_TripleMu_5_5_3',
#  'L1_UnpairedBunchBptxMinus',
#  'L1_UnpairedBunchBptxPlus',
#  'L1_ZDC14_AND',
#  'L1_ZDC14_AND_BptxAND',
#  'L1_ZDC14_OR',
#  'L1_ZDC14_OR_BptxAND',
#  'L1_ZDC16_AND',
#  'L1_ZDC16_AND_BptxAND',
#  'L1_ZDC16_OR',
#  'L1_ZDC16_OR_BptxAND',
#  'L1_ZDC18_AND',
#  'L1_ZDC18_AND_BptxAND',
#  'L1_ZDC18_OR',
#  'L1_ZDC18_OR_BptxAND',
#  'L1_ZDC1n_AND_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_AND_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_AsymXOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_AsymXOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_AND_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_AND_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_AsymXOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_AsymXOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_OR_BptxAND',
#  'L1_ZDC1n_Bkp1_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_XOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp1_XOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_AND_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_AND_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_AsymXOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_AsymXOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_OR_BptxAND',
#  'L1_ZDC1n_Bkp2_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_XOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp2_XOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_AND_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_AND_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_AsymXOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_AsymXOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_OR_BptxAND',
#  'L1_ZDC1n_Bkp3_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_XOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_Bkp3_XOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_OR_BptxAND',
#  'L1_ZDC1n_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC1n_XOR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC1n_XOR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC22_AND',
#  'L1_ZDC22_AND_BptxAND',
#  'L1_ZDC22_OR',
#  'L1_ZDC22_OR_BptxAND',
#  'L1_ZDC28_AND',
#  'L1_ZDC28_AND_BptxAND',
#  'L1_ZDC28_OR',
#  'L1_ZDC28_OR_BptxAND',
#  'L1_ZDC2n_Bkp1_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC2n_Bkp1_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC2n_Bkp2_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC2n_Bkp2_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC2n_Bkp3_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC2n_Bkp3_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC2n_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC2n_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC3n_Bkp1_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC3n_Bkp1_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC3n_Bkp2_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC3n_Bkp2_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC3n_Bkp3_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC3n_Bkp3_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDC3n_OR_MinimumBiasHF1_AND_BptxAND',
#  'L1_ZDC3n_OR_MinimumBiasHF2_AND_BptxAND',
#  'L1_ZDCM14',
#  'L1_ZDCM14_BptxAND',
#  'L1_ZDCM16',
#  'L1_ZDCM16_BptxAND',
#  'L1_ZDCM18',
#  'L1_ZDCM18_BptxAND',
#  'L1_ZDCM22',
#  'L1_ZDCM22_BptxAND',
#  'L1_ZDCM28',
#  'L1_ZDCM28_BptxAND',
#  'L1_ZDCP14',
#  'L1_ZDCP14_BptxAND',
#  'L1_ZDCP16',
#  'L1_ZDCP16_BptxAND',
#  'L1_ZDCP18',
#  'L1_ZDCP18_BptxAND',
#  'L1_ZDCP22',
#  'L1_ZDCP22_BptxAND',
#  'L1_ZDCP28',
#  'L1_ZDCP28_BptxAND',
#  'L1_ZeroBias',
#  'L1_ZeroBias_copy',
#  'L1_UnprefireableEvent_TriggerRules',
#  'L1_UnprefireableEvent_FirstBxInTrain',
#  'L1_FinalOR_BXmin1',
#  'L1_FinalOR_BXmin2',
#  'HLTriggerFirstPath',
#  'DST_PFScouting_DoubleMuon',
#  'DST_PFScouting_DoubleEG',
#  'DST_PFScouting_JetHT',
#  'DST_PFScouting_DatasetMuon',
#  'DST_PFScouting_AXONominal',
#  'DST_PFScouting_AXOTight',
#  'DST_PFScouting_SingleMuon',
#  'HLT_EphemeralPhysics',
#  'HLT_EphemeralZeroBias',
#  'HLT_EcalCalibration',
#  'HLT_HcalCalibration',
#  'HLT_HcalNZS',
#  'HLT_HcalPhiSym',
#  'HLT_Random',
#  'HLT_Physics',
#  'HLT_ZeroBias',
#  'HLT_ZeroBias_Alignment',
#  'HLT_ZeroBias_Beamspot',
#  'HLT_ZeroBias_IsolatedBunches',
#  'HLT_ZeroBias_FirstBXAfterTrain',
#  'HLT_ZeroBias_FirstCollisionAfterAbortGap',
#  'HLT_ZeroBias_FirstCollisionInTrain',
#  'HLT_ZeroBias_LastCollisionInTrain',
#  'HLT_HT300_Beamspot',
#  'HLT_IsoTrackHB',
#  'HLT_IsoTrackHE',
#  'HLT_PFJet40_GPUvsCPU',
#  'HLT_AK8PFJet380_SoftDropMass30',
#  'HLT_AK8PFJet400_SoftDropMass30',
#  'HLT_AK8PFJet425_SoftDropMass30',
#  'HLT_AK8PFJet450_SoftDropMass30',
#  'HLT_AK8DiPFJet250_250_SoftDropMass40',
#  'HLT_AK8DiPFJet250_250_SoftDropMass50',
#  'HLT_AK8DiPFJet260_260_SoftDropMass30',
#  'HLT_AK8DiPFJet260_260_SoftDropMass40',
#  'HLT_AK8DiPFJet270_270_SoftDropMass30',
#  'HLT_AK8DiPFJet280_280_SoftDropMass30',
#  'HLT_AK8DiPFJet290_290_SoftDropMass30',
#  'HLT_CaloJet500_NoJetID',
#  'HLT_CaloJet550_NoJetID',
#  'HLT_DoubleMu5_Upsilon_DoubleEle3_CaloIdL_TrackIdL',
#  'HLT_DoubleMu3_DoubleEle7p5_CaloIdL_TrackIdL_Upsilon',
#  'HLT_Trimuon5_3p5_2_Upsilon_Muon',
#  'HLT_TrimuonOpen_5_3p5_2_Upsilon_Muon',
#  'HLT_DoubleEle25_CaloIdL_MW',
#  'HLT_DoubleEle27_CaloIdL_MW',
#  'HLT_DoubleEle33_CaloIdL_MW',
#  'HLT_DoubleEle24_eta2p1_WPTight_Gsf',
#  'HLT_DoubleEle8_CaloIdM_TrackIdM_Mass8_DZ_PFHT350',
#  'HLT_DoubleEle8_CaloIdM_TrackIdM_Mass8_PFHT350',
#  'HLT_Mu27_Ele37_CaloIdL_MW',
#  'HLT_Mu37_Ele27_CaloIdL_MW',
#  'HLT_Mu37_TkMu27',
#  'HLT_DoubleMu4_3_Bs',
#  'HLT_DoubleMu4_3_Jpsi',
#  'HLT_DoubleMu4_3_LowMass',
#  'HLT_DoubleMu4_LowMass_Displaced',
#  'HLT_Mu0_L1DoubleMu',
#  'HLT_Mu4_L1DoubleMu',
#  'HLT_DoubleMu2_Jpsi_LowPt',
#  'HLT_DoubleMu4_3_Photon4_BsToMMG',
#  'HLT_DoubleMu4_3_Displaced_Photon4_BsToMMG',
#  'HLT_DoubleMu3_Trk_Tau3mu',
#  'HLT_DoubleMu3_TkMu_DsTau3Mu',
#  'HLT_DoubleMu4_Mass3p8_DZ_PFHT350',
#  'HLT_DoubleMu4_MuMuTrk_Displaced',
#  'HLT_Mu3_PFJet40',
#  'HLT_Mu7p5_L2Mu2_Jpsi',
#  'HLT_Mu7p5_L2Mu2_Upsilon',
#  'HLT_Mu3_L1SingleMu5orSingleMu7',
#  'HLT_Mu0_Barrel',
#  'HLT_Mu0_Barrel_L1HP10',
#  'HLT_Mu0_Barrel_L1HP11',
#  'HLT_Mu9_Barrel_L1HP10_IP6',
#  'HLT_Mu10_Barrel_L1HP11_IP6',
#  'HLT_DoublePhoton33_CaloIdL',
#  'HLT_DoublePhoton70',
#  'HLT_DoublePhoton85',
#  'HLT_DiEle27_WPTightCaloOnly_L1DoubleEG',
#  'HLT_Ele30_WPTight_Gsf',
#  'HLT_Ele32_WPTight_Gsf',
#  'HLT_Ele35_WPTight_Gsf',
#  'HLT_Ele38_WPTight_Gsf',
#  'HLT_Ele40_WPTight_Gsf',
#  'HLT_Ele32_WPTight_Gsf_L1DoubleEG',
#  'HLT_IsoMu20',
#  'HLT_IsoMu24',
#  'HLT_IsoMu24_eta2p1',
#  'HLT_IsoMu27',
#  'HLT_UncorrectedJetE30_NoBPTX',
#  'HLT_UncorrectedJetE30_NoBPTX3BX',
#  'HLT_UncorrectedJetE60_NoBPTX3BX',
#  'HLT_UncorrectedJetE70_NoBPTX3BX',
#  'HLT_L1SingleMuCosmics',
#  'HLT_L2Mu10_NoVertex_NoBPTX3BX',
#  'HLT_L2Mu10_NoVertex_NoBPTX',
#  'HLT_L2Mu45_NoVertex_3Sta_NoBPTX3BX',
#  'HLT_L2Mu40_NoVertex_3Sta_NoBPTX3BX',
#  'HLT_L2Mu23NoVtx_2Cha',
#  'HLT_L2Mu23NoVtx_2Cha_CosmicSeed',
#  'HLT_DoubleL2Mu30NoVtx_2Cha_CosmicSeed_Eta2p4',
#  'HLT_DoubleL2Mu30NoVtx_2Cha_Eta2p4',
#  'HLT_DoubleL2Mu50',
#  'HLT_DoubleL2Mu23NoVtx_2Cha_CosmicSeed',
#  'HLT_DoubleL2Mu25NoVtx_2Cha_CosmicSeed',
#  'HLT_DoubleL2Mu25NoVtx_2Cha_CosmicSeed_Eta2p4',
#  'HLT_DoubleL2Mu23NoVtx_2Cha',
#  'HLT_DoubleL2Mu25NoVtx_2Cha',
#  'HLT_DoubleL2Mu25NoVtx_2Cha_Eta2p4',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL',
#  'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ',
#  'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8_PFJet30',
#  'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ_Mass8',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass3p8',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8_CaloJet30',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8_AK8PFJet30',
#  'HLT_Mu17_TrkIsoVVL_Mu8_TrkIsoVVL_DZ_Mass8_AK8CaloJet30',
#  'HLT_Mu19_TrkIsoVVL_Mu9_TrkIsoVVL_DZ_Mass3p8',
#  'HLT_Mu30_TkMu0_Psi',
#  'HLT_Mu30_TkMu0_Upsilon',
#  'HLT_Mu25_TkMu0_Phi',
#  'HLT_Mu15',
#  'HLT_Mu20',
#  'HLT_Mu27',
#  'HLT_Mu50',
#  'HLT_Mu55',
#  'HLT_CascadeMu100',
#  'HLT_HighPtTkMu100',
#  'HLT_DiPFJetAve40',
#  'HLT_DiPFJetAve60',
#  'HLT_DiPFJetAve80',
#  'HLT_DiPFJetAve140',
#  'HLT_DiPFJetAve200',
#  'HLT_DiPFJetAve260',
#  'HLT_DiPFJetAve320',
#  'HLT_DiPFJetAve400',
#  'HLT_DiPFJetAve500',
#  'HLT_DiPFJetAve60_HFJEC',
#  'HLT_DiPFJetAve80_HFJEC',
#  'HLT_DiPFJetAve100_HFJEC',
#  'HLT_DiPFJetAve160_HFJEC',
#  'HLT_DiPFJetAve220_HFJEC',
#  'HLT_DiPFJetAve260_HFJEC',
#  'HLT_DiPFJetAve300_HFJEC',
#  'HLT_DiPFJetAve180_PPSMatch_Xi0p3_QuadJet_Max2ProtPerRP',
#  'HLT_AK8PFJet40',
#  'HLT_AK8PFJet60',
#  'HLT_AK8PFJet80',
#  'HLT_AK8PFJet140',
#  'HLT_AK8PFJet200',
#  'HLT_AK8PFJet260',
#  'HLT_AK8PFJet320',
#  'HLT_AK8PFJet400',
#  'HLT_AK8PFJet450',
#  'HLT_AK8PFJet500',
#  'HLT_AK8PFJet550',
#  'HLT_PFJet40',
#  'HLT_PFJet60',
#  'HLT_PFJet80',
#  'HLT_PFJet110',
#  'HLT_PFJet140',
#  'HLT_PFJet200',
#  'HLT_PFJet260',
#  'HLT_PFJet320',
#  'HLT_PFJet400',
#  'HLT_PFJet450',
#  'HLT_PFJet500',
#  'HLT_PFJet550',
#  'HLT_PFJetFwd40',
#  'HLT_PFJetFwd60',
#  'HLT_PFJetFwd80',
#  'HLT_PFJetFwd140',
#  'HLT_PFJetFwd200',
#  'HLT_PFJetFwd260',
#  'HLT_PFJetFwd320',
#  'HLT_PFJetFwd400',
#  'HLT_PFJetFwd450',
#  'HLT_PFJetFwd500',
#  'HLT_AK8PFJetFwd40',
#  'HLT_AK8PFJetFwd60',
#  'HLT_AK8PFJetFwd80',
#  'HLT_AK8PFJetFwd140',
#  'HLT_AK8PFJetFwd200',
#  'HLT_AK8PFJetFwd260',
#  'HLT_AK8PFJetFwd320',
#  'HLT_AK8PFJetFwd400',
#  'HLT_AK8PFJetFwd450',
#  'HLT_AK8PFJetFwd500',
#  'HLT_PFHT180',
#  'HLT_PFHT250',
#  'HLT_PFHT370',
#  'HLT_PFHT430',
#  'HLT_PFHT510',
#  'HLT_PFHT590',
#  'HLT_PFHT680',
#  'HLT_PFHT780',
#  'HLT_PFHT890',
#  'HLT_PFHT1050',
#  'HLT_PFHT500_PFMET100_PFMHT100_IDTight',
#  ...]

# %%
ak.min(file["Events"]["ScoutingJet_mass"].array()) #Why is this negative?
# Out:
# -0.7373047

# %% [markdown]
# Different fields correspond to different types of data in the event.
#
# Here the main ones we will be using are:
# - Scouting jets (ScoutingJet)
# - Scouting electrons (ScoutingElectron)
# - Scouting muons no (ScoutingMuonNoVtx)
# - Level 1 Jets (L1Jet)
# - Level 1 Electron/Photons (L1EG)
# - Level 1 Muon (L1Muon)
#
# The "L1" prefix means that these are objects that are reconstructed in electronics at the Level 1 Trigger.
# The "Scouting" prefix means that these are objects that are reconstructed in software at the High Level Trigger. (https://cms.cern/index.php/detector/triggering-and-data-acquisition)
#
# ## Questions to discuss
# **What are jets, electrons, photons and muons?**
# * Jets: Cone of hadrons (composite particles, baryons or mesons - odd quark # vs even) from "hadronization of quarks and gluons" -> hadronization happens because quarks and gluons have a color charge, and QCD confinement only allows for colorless states. Color charges determine what strong force interaction particles will have with one another. Basically, jets are just big spews of hadrons. Seen in hadron calorimeter
# * Electrons: Electrically charged fundamental particles (leptons), seen in EM calorimeter, subject to electric and magnetic fields
# * Photons: Neutral, massless "particles" that regulate the electromagnetic force, seen in EM calorimeter
# * Muons: Negatively charged leptons, more massive than electrons, come from collisions between particles + cosmic rays (or proton-tungsten collisions in the [Mu2e](https://mu2e.fnal.gov/how_does_it_work.shtml) ? pions -> muons), detected by the muon chambers
#
# **What parts of the CMS detector are used for identifying these objects** https://cms.cern/detector/
# * Jets: Hadron calorimeter (charged hadrons bend, neutral ones do not)
# * Electrons + Photons: EM calorimeter
# * Muons: Muon chambers
#
# Visit [CMS Detector Slice](https://cds.cern.ch/record/2120661) for visual aid!

# %% [markdown]
# ---
# The most important variables we will be looking at are the pT, eta, phi and mass of each of these objects. For example 'ScoutingJet_pt',''ScoutingJet_eta','ScoutingJet_phi','ScoutingJet_mass'.
#
# See https://tikz.net/axis3d_cms/ for an illustration of the CMS co-ordinate system.
#
# ## Questions to discuss
# **What is pT and why is it useful?**
#
# pT is the momentum component that is perpendicular/transverse to the beam line (the z axis). Using just pT guarantees that you're only paying attention to the physics at the collision point (vertex?) as opposed to the momentum along the beamline, which could be from other beam particles.
# Source: ["Study of Transversal Momentum, Phi, and Eta"](https://www.i2u2.org/elab/cms/posters/display.jsp?type=paper&name=study_of_transversal_momentum_phi_and_eta-cms-daisy-fetsko-mills_godwin_high_school-henrico-va-2014.0302.data)
#
# **What is the value of eta if a particle passes close to the beam-pipe? What is eta if the particle is perpendicular to the beampipe?** (https://en.wikipedia.org/wiki/Pseudorapidity)
#
# Eta is the "pseudorapidity," which defines the angle of the particle in relation to the beam axis. The lower eta is, the closer to the beam it is, making it harder to distinguish. If eta is truly perpendicular to the beamline, it is infinite, because of its relationship with theta -> eta = ln(tan(theta/2)). Theta is the angle between the beamline and momentum. Sources: ["CMS coordinate system"](https://tikz.net/axis3d_cms/) and ["Pseudorapidity"](https://en.wikipedia.org/wiki/Pseudorapidity)
#
# **What is phi and mass?**
#
# Phi is the angle between the x axis (pointing towards the center of the LHC) and the pT vector. It is also known as the azimuthal (azimuth = "angle formed between a reference direction and a line from the observer to a point of interest". Source:["Azimuth"](https://en.wikipedia.org/wiki/Azimuth#:~:text=The%20azimuth%20is%20the%20angle%20formed%20between%20a,as%20the%20reference%20direction%20orthogonal%20to%20the%20zenith.) ) and/or scattering angle. Graphs of phi vs. eta can represent the direction of an outgoing particle and help determine the distance between two particles.
# Source: ["Pseudo-Rapidity, Azimuthal Angle, and Transverse Momentum"](https://www.phys.ufl.edu/~rfield/cdf/chgjet/etaphi.html)
#
# Particle mass is measured in electronvolts, rather than an SI unit like kg, because they are so incredibly small. Known equations, like E^2 = (mc^2)^2 + (pc)^2, relate energy, momentum, and mass, allowing us to determine the mass of particles from energy signatures in the detector. We can also use the "kinematic characteristics" of measured particles to reconstruct the mass of their parent particle.
# Sources: ["How CMS Detect Particles"](https://indico.cern.ch/event/464777/contributions/1971633/attachments/1197560/1742904/cmsDetector_detectParticles.pdf) and ["Measuring Particle Masses"](https://van.physics.illinois.edu/ask/listing/1209#:~:text=Typically%2C%20subatomic%20particle%20masses%20are%20determined%20by%20the,momentum%20and%20c%20is%20the%20speed%20of%20light.)
#
# ---
#
# We can inspect these object like this:

# %%
# LHC run number
jet_pt = file["Events"]["ScoutingJet_pt"].array() # Takes file tree, looks at events, looks at data within events, presents it in array
jet_pt
# Out:
# <Array [[], [26.7], ..., [23.4, 23.4, 21.3]] type='431555 * var * float32'>

# %% [markdown]
# Each row here corresponds to an "event", also known as a collision. During a collision different numbers of jets can be produced. Here, the first collision produced 0 jets, the second collision produced one jet with pt=26.7 GeV, and the 6th collision produced 5 jets!
#
# We can use the awkward array and numpy libraries to perform some calculations on the jet pt. (References: https://awkward-array.org/doc/main/reference/generated/ak.mean.html & https://numpy.org/doc/stable/reference/generated/numpy.median.html)

# %%
ak.num(jet_pt, axis=1) # total number of jets per event
# Out:
# <Array [0, 1, 1, 2, 0, 5, 4, 3, ..., 4, 3, 3, 6, 1, 5, 3] type='431555 * int64'>

# %%
ak.sum(jet_pt, axis=1) # total pt of jets per event
# Out:
# <Array [0, 26.7, 24.9, 181, 0, ..., 144, 26, 433, 68.1] type='431555 * float32'>

# %%
ak.mean(jet_pt) # mean jet pt per event
# Out:
# 53.67741283067713

# %%
np.median(ak.flatten(jet_pt)) # median jet pt per event
# Out:
# 29.899792

# %% [markdown]
# # Questions to answer:
#
# **How many collision events are in this file?**
#
# 431,555 events
#
# **What is the maximum jet pt in an event** (https://awkward-array.org/doc/main/reference/generated/ak.max.html)
#
# The maximum jet pt in any event is 1235.5298 GeV.
#
# **What is the minimum jet pt in an event?**
#
# The minimum jet pt in any event is 20.0 GeV.
#
# **What are the mean, median, maximum and minimum values of jet pt, eta, phi and mass?**
#
# Jet pt:
#
# * Mean: 53.67741283067713
#
# * Median: 29.899791717529297
#
# * Maximum: 1235.52978515625
#
# * Minimum: 20.0
#
# Eta:
#
# * Mean: 0.010506778174641298
#
# * Median: 0.025064468383789062
#
# * Maximum: 2.95703125
#
# * Minimum: -2.978515625
#
# Phi:
#
# * Mean: 0.005393391787886657
#
# * Median: 0.002682924270629883
#
# * Maximum: 3.1416015625
#
# * Minimum: -3.1416015625
#
# Mass:
#
# * Mean: 8.601295693829671
#
# * Median: 6.55078125
#
# * Maximum: 149.75
#
# * Minimum: -0.7373046875
#
# **What are the ranges of ScoutingElectron pt, eta, phi and mass, and ScoutingMuonNoVtx pt, eta, phi and mass? You may want to write a for loop to extract all of these.**
#
# Scouting Electron:
#
# * pt Range: (3.9863281, 745.5)
#
# * eta Range: (-2.5, 2.5)
#
# * phi Range: (-3.140625, 3.140625)
#
# * m Range: (-2.95043e-05, 2.3931265e-05)
#
# ScoutingMuonNoVtx:
#
# * pt Range: (1.0, 74688.0)
#
# * eta Range: (-2.4003906, 2.4003906)
#
# * phi Range: (-3.140625, 3.140625)
#
# * m Range: (-0.0003452301, 0.0003452301)
#
# See https://uproot.readthedocs.io/en/latest/basic.html for more information on opening and inspecting root files.

# %%
# How many collision events? I think 431555, but let's find out!
tot = ak.num(jet_pt,axis = 0) # Every event has a jet_pt value, even if it is zero. axis = 0 counts number of events, not considering number of entries in each row.
tot
# Out:
# 431555

# %%
# What is the max jet pt in an event?
tot_max = ak.max(jet_pt) # don't add an axis because we want the max out of all events
tot_max
# Out:
# 1235.5298

# %%
# What is each event's max jet pt?
each_max = ak.max(jet_pt, axis = 1)
each_max
# Out:
# <Array [None, 26.7, 24.9, 97.6, ..., 26, 211, 23.4] type='431555 * ?float32'>

# %%
# What is the overall minimum jet pt?
tot_min = ak.min(jet_pt)
tot_min
# Out:
# 20.0

# %%
# What is the minimum of each event?
each_min = ak.min(jet_pt, axis = 1)
each_min
# Out:
# <Array [None, 26.7, 24.9, 83.6, ..., 26, 24.8, 21.3] type='431555 * ?float32'>

# %%
# What are the mean, median, maximum and minimum values of jet pt, eta, phi and mass?
scouting_jet = {
    "jet pt" : file["Events"]["ScoutingJet_pt"].array(),
    "eta" : file["Events"]["ScoutingJet_eta"].array(),
    "phi" : file["Events"]["ScoutingJet_phi"].array(),
    "mass" : file["Events"]["ScoutingJet_mass"].array()
}

for key, value in scouting_jet.items():
    print(key)
    print(f"Mean: {ak.mean(value)}")
    print(f"Median: {np.median(ak.flatten(value))}")
    print(f"Maximum: {ak.max(value)}")
    print(f"Minimum: {ak.min(value)}")
    print("    ")

# I'm sure there's a more efficient way to do this
# Out:
# jet pt
# Mean: 53.67741283067713
# Median: 29.899791717529297
# Maximum: 1235.52978515625
# Minimum: 20.0
#
# eta
# Mean: 0.010506778174641298
# Median: 0.025064468383789062
# Maximum: 2.95703125
# Minimum: -2.978515625
#
# phi
# Mean: 0.005393391787886657
# Median: 0.002682924270629883
# Maximum: 3.1416015625
# Minimum: -3.1416015625
#
# mass
# Mean: 8.601295693829671
# Median: 6.55078125
# Maximum: 149.75
# Minimum: -0.7373046875

# %%
# What are the ranges of ScoutingElectron pt, eta, phi and mass, and ScoutingMuonNoVtx pt, eta, phi and mass?
# You may want to write a for loop to extract all of these.
def minmax(arr):
    min = ak.min(arr)
    max = ak.max(arr)
    return (min, max)

scouting_em = {
    "electron pt" : file["Events"]["ScoutingElectron_pt"].array(),
    "electron eta" : file["Events"]["ScoutingElectron_eta"].array(),
    "electron phi" : file["Events"]["ScoutingElectron_phi"].array(),
    "electron m" : file["Events"]["ScoutingElectron_m"].array(), # No ScoutingElectron_mass?
    "muon pt" : file["Events"]["ScoutingMuonNoVtx_pt"].array(),
    "muon eta" : file["Events"]["ScoutingMuonNoVtx_eta"].array(),
    "muon phi" : file["Events"]["ScoutingMuonNoVtx_phi"].array(),
    "muon m" : file["Events"]["ScoutingMuonNoVtx_m"].array() # Same thing here?
}

for key, value in scouting_em.items(): 
    print(f"{key} range: {minmax(value)}")
# Out:
# electron pt range: (3.9863281, 745.5)
# electron eta range: (-2.5, 2.5)
# electron phi range: (-3.140625, 3.140625)
# electron m range: (-2.95043e-05, 2.3931265e-05)
# muon pt range: (1.0, 74688.0)
# muon eta range: (-2.4003906, 2.4003906)
# muon phi range: (-3.140625, 3.140625)
# muon m range: (-0.0003452301, 0.0003452301)
