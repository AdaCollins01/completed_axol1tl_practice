# %%
import keras
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import uproot
import awkward as ak
# %matplotlib inline

from sklearn.preprocessing import RobustScaler

# import basic libraries 
import h5py
import pandas as pd

from keras.models import Model
from keras.layers import Input, add
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.layers import Layer, Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils
# Out:
# 2024-06-21 08:57:05.179598: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /cvmfs/cms.cern.ch/el9_amd64_gcc12/external/py3-numpy/1.24.3-a3a65cbc18c6a98e06451d4329e3ea47/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
#Opening file
filename = "/uscms/home/jpearkes/eos/forAda/scouting_nano.root" # originally from root://hip-cms-se.csc.fi//store/user/pinkaew/scouting_nano_prod_golden/ScoutingPFRun3/crab_ScoutingPFRun3_Run2024D-v1_380385-380470_Golden/240517_205837/0000/scouting_nano_399.root
file = uproot.open(filename)

#Calling files
jet_pt = file["Events"]["L1Jet_pt"].array()
jet_eta = file["Events"]["L1Jet_eta"].array()
jet_phi = file["Events"]["L1Jet_phi"].array()

# %%
jet_pt = np.asarray(ak.fill_none(ak.pad_none(jet_pt, 4, clip=True), 0.0)) #replace missing values with none, increase value to target length with ak.pad_none
jet_eta = np.asarray(ak.fill_none(ak.pad_none(jet_eta, 4, clip=True), 0.0))
jet_phi = np.asarray(ak.fill_none(ak.pad_none(jet_phi, 4, clip=True), 0.0))

jet_eta.shape #np function that gives us shape of array - (rows, columns) - 4 columns bc we said so with ak.pad_none
# Out:
# (431555, 4)

# %%
dataset = np.hstack([jet_pt,jet_eta,jet_phi]) #puts all the arrays next to eachother
dataset
# Out:
# array([[ 2.30000000e+01,  2.20000000e+01,  1.80000000e+01, ...,
#         -4.10705566e-01, -1.36767578e+00,  1.87060547e+00],
#        [ 1.60000000e+01,  1.20000000e+01,  1.15000000e+01, ...,
#          8.26538086e-01, -2.84667969e+00,  7.39501953e-01],
#        [ 2.00000000e+01,  1.35000000e+01,  1.90000000e+01, ...,
#         -6.26831055e-02,  1.34838867e+00,  2.47949219e+00],
#        ...,
#        [ 2.80000000e+01,  2.55000000e+01,  1.85000000e+01, ...,
#         -1.01977539e+00,  2.91455078e+00,  3.91479492e-01],
#        [ 2.14500000e+02,  9.70000000e+01,  8.10000000e+01, ...,
#          3.04504395e-01,  1.52246094e+00,  5.65551758e-01],
#        [ 2.15000000e+01,  1.90000000e+01,  1.90000000e+01, ...,
#         -1.62866211e+00,  1.34838867e+00, -1.71557617e+00]])

# %%
# We want some data for training, some for validating, and some for testing
# Validating combats overfitting while testing analyzes the predictive power of the network
dataset_size = dataset.shape[0] #gives you number of rows
data_train = dataset[0:int(dataset_size/2)] #50%
data_valid = dataset[int(dataset_size/2):int(dataset_size/4*3)] # 25% - used for tuning hyper-parameters
data_test = dataset[int(dataset_size/4*3):] # 25% - hold out for now

print(data_train.shape,data_test.shape, data_valid.shape)
# Out:
# (215777, 12) (107889, 12) (107889, 12)

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        print(batch)
        dim = tf.shape(z_mean)[1]
        print(dim)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
#Encoder

latent_dim = 4

encoder_inputs = keras.Input(shape=(12))
x = layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = False)(encoder_inputs)
x1 = layers.Dense(32, activation="relu")(x)
x2 = layers.Dense(16, activation="relu")(x1)
x3 = layers.Dense(8, activation="relu")(x2)
z_mean = layers.Dense(latent_dim, name="z_mean")(x3)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x3)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Decoder

latent_inputs = keras.Input(shape=(latent_dim,))
x4 = layers.Dense(16, activation="relu")(latent_inputs)
norm_layer_1 = layers.BatchNormalization(name="norm_1")(x4)
x5 = layers.Dense(32, activation="relu")(norm_layer_1)
norm_layer_2 = layers.BatchNormalization(name="norm_2")(x5)
x6 = layers.Dense(64, activation="relu")(norm_layer_2)
norm_layer_3 = layers.BatchNormalization(name="norm_3")(x6)
x7 = layers.Dense(128, activation="relu")(norm_layer_3)
x8 = layers.Dense(12,kernel_initializer='zeros', activation='linear')(x7)
decoder_outputs = tf.keras.layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = True)(x8)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

#Build Model

class VAE(keras.Model):
    def __init__(self, encoder, decoder,alpha = 1, beta = 0.001, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
        self.reco_scale = alpha * (1 - beta)
        self.kl_scale = beta
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.total_val_loss_tracker = keras.metrics.Mean(name="total_val_loss")
        self.reconstruction_val_loss_tracker = keras.metrics.Mean(name="val_reco_loss")
        self.kl_val_loss_tracker = keras.metrics.Mean(name="val_kl_loss")


    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    

    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            #MSE = keras.losses.MeanSquaredLogarithmicError(reduction="auto", name="mean_squared_error")
            #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
            MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
            reconstruction_loss = self.reco_scale * tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        
        grads = tape.gradient(total_loss, self.trainable_weights)

        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        
        #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
        MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
        reconstruction_loss = self.reco_scale* tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
                    
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        
        total_loss = reconstruction_loss + kl_loss
        
        self.total_val_loss_tracker.update_state(total_loss)
        self.reconstruction_val_loss_tracker.update_state(reconstruction_loss)
        self.kl_val_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_val_loss_tracker.result(),
            "reco_loss": self.reconstruction_val_loss_tracker.result(),
            "kl_loss": self.kl_val_loss_tracker.result()

      }
# Out:
# Tensor("sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 12)]         0           []
#
#  normalization_4 (Normalization  (None, 12)          0           ['input_5[0][0]']
#  )
#
#  dense_16 (Dense)               (None, 32)           416         ['normalization_4[0][0]']
#
#  dense_17 (Dense)               (None, 16)           528         ['dense_16[0][0]']
#
#  dense_18 (Dense)               (None, 8)            136         ['dense_17[0][0]']
#
#  z_mean (Dense)                 (None, 4)            36          ['dense_18[0][0]']
#
#  z_log_var (Dense)              (None, 4)            36          ['dense_18[0][0]']
#
#  sampling_2 (Sampling)          (None, 4)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 1,152
# Trainable params: 1,152
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 4)]               0
#
#  dense_19 (Dense)            (None, 16)                80
#
#  norm_1 (BatchNormalization)  (None, 16)               64
#
#  dense_20 (Dense)            (None, 32)                544
#
#  norm_2 (BatchNormalization)  (None, 32)               128
#
#  dense_21 (Dense)            (None, 64)                2112
#
#  norm_3 (BatchNormalization)  (None, 64)               256
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dense_23 (Dense)            (None, 12)                1548
#
#  normalization_5 (Normalizat  (None, 12)               0
#  ion)
#
# =================================================================
# Total params: 13,052
# Trainable params: 12,828
# Non-trainable params: 224
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0, patience=5, verbose = 1,restore_best_weights=True)
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0001,clipnorm=10.0))
history = vae.fit(data_train, validation_data = (data_valid, data_valid), epochs=10, batch_size=16, callbacks = [callback],shuffle=False)
# Out:
# Epoch 1/10
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 13484/13487 [============================>.] - ETA: 0s - loss: 1149366098491129856000.0000 - reconstruction_loss: 1219680332208196812800.0000 - kl_loss: 5993950255425519616.0000Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 13487/13487 [==============================] - 34s 2ms/step - loss: 1149388667781231411200.0000 - reconstruction_loss: 1219408990330647740416.0000 - kl_loss: 5992617097576841216.0000 - val_loss: 634.5397 - val_reco_loss: 634.1368 - val_kl_loss: 0.4032
# Epoch 2/10
# 13487/13487 [==============================] - 30s 2ms/step - loss: 390.0084 - reconstruction_loss: 214.2754 - kl_loss: 0.4752 - val_loss: 352.1280 - val_reco_loss: 351.6726 - val_kl_loss: 0.4552
# Epoch 3/10
# 13487/13487 [==============================] - 30s 2ms/step - loss: 61.6671 - reconstruction_loss: 55.0547 - kl_loss: 0.5300 - val_loss: 252.1969 - val_reco_loss: 251.7173 - val_kl_loss: 0.4791
# Epoch 4/10
# 13487/13487 [==============================] - 31s 2ms/step - loss: 46.7064 - reconstruction_loss: 44.7172 - kl_loss: 0.5294 - val_loss: 201.2987 - val_reco_loss: 200.8106 - val_kl_loss: 0.4881
# Epoch 5/10
# 13487/13487 [==============================] - 29s 2ms/step - loss: 41.6392 - reconstruction_loss: 40.5748 - kl_loss: 0.5093 - val_loss: 170.1120 - val_reco_loss: 169.6242 - val_kl_loss: 0.4886
# Epoch 6/10
# 13487/13487 [==============================] - 28s 2ms/step - loss: 38.6503 - reconstruction_loss: 38.2111 - kl_loss: 0.4819 - val_loss: 149.1959 - val_reco_loss: 148.7127 - val_kl_loss: 0.4836
# Epoch 7/10
# 13487/13487 [==============================] - 26s 2ms/step - loss: 37.4387 - reconstruction_loss: 36.7921 - kl_loss: 0.4555 - val_loss: 133.5221 - val_reco_loss: 133.0450 - val_kl_loss: 0.4771
# Epoch 8/10
# 13487/13487 [==============================] - 25s 2ms/step - loss: 36.6293 - reconstruction_loss: 36.0506 - kl_loss: 0.4307 - val_loss: 121.6794 - val_reco_loss: 121.2098 - val_kl_loss: 0.4692
# Epoch 9/10
# 13487/13487 [==============================] - 25s 2ms/step - loss: 36.1048 - reconstruction_loss: 35.3900 - kl_loss: 0.4103 - val_loss: 112.2809 - val_reco_loss: 111.8200 - val_kl_loss: 0.4610
# Epoch 10/10
# 13487/13487 [==============================] - 28s 2ms/step - loss: 35.5133 - reconstruction_loss: 34.9768 - kl_loss: 0.3861 - val_loss: 104.7892 - val_reco_loss: 104.3373 - val_kl_loss: 0.4519

# %%
z_mean, z_log_var, z = vae.encoder.predict(data_valid)
output = vae.decoder.predict(z)
# Out:
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 3372/3372 [==============================] - 3s 772us/step
# 3372/3372 [==============================] - 2s 694us/step

# %%
print(history.history.keys())

plt.plot(history.history['loss'],label="train")
plt.plot(history.history['val_loss'],label="validation")
#plt.yscale('log')
plt.title('model loss')
plt.yscale('log')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend( loc='upper right',frameon = False)
plt.show()
# Out:
# dict_keys(['loss', 'reconstruction_loss', 'kl_loss', 'val_loss', 'val_reco_loss', 'val_kl_loss'])

# %%
decoded_data = output.reshape(output.shape[0], 4,3) # Do the three dimensions correspond to the three variables? Bc I feel like no
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,3)

print(decoded_data.shape,data_test.shape, data_valid.shape)

#Jet Pt plot
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,0,0],decoded_data[:,0,0]],bins=100,histtype='step',range = (0,100), label = ['Input','Prediction'])
plt.xlabel(r"$p_T$ [GeV]")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')

#But hey this looks great!
# Out:
# (107889, 4, 3) (107889, 12) (107889, 12)
# Text(0.5, 1.0, '1st Jet')

# %% [markdown]
# # Notes
#
# **Might need to check the dataset shapes here**
#
# Everything ran fine, with the exception of the model loss? It seems odd that validation = 0 for so much longer than training period.
#
# **What is the training step doing?**
#
# The training step relies on the 50% of data that we set aside in the beginning. We've defined a loss function that we want to minimize (I assume) and the Gradient Tape gives us more control over the layer we've defined ([Source](https://stackoverflow.com/questions/53953099/what-is-the-purpose-of-the-tensorflow-gradient-tape)). The "trainable weights" change throughout the process so as to minimize loss.
#
# How do the trainable weights actually change? Just it just try out a bunch of different configurations?
#
# **What are hyperparameters and what happen when you change them?**
#
# Hyperparameters are settings that determine how the neural networks learn ([Source](https://pyimagesearch.com/2021/05/31/hyperparameter-tuning-for-deep-learning-with-scikit-learn-keras-and-tensorflow/)). Here, we have qualities like learning rate, batch size, and number of epochs.
# - Patience: How many epochs to continue running even if model is not improving ([Source](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/))
# - Verbose: When verbose = 1, program will return the number of the epoch that the network stopped at (Source above).
# - Epochs: Increasing the epoch size gives the program more training opportunities, thereby minimizing the loss even more. However, it does increase computation time. I increased the epoch size to 15, and it stopped it after 7/15 runs, with a 37.1% loss. However, this was also considering the training from the last 10 epochs. When I graphed the model loss, train decreased while validation increased.
# - Learning rate: Changing the learning rate from 0.0001 to 0.1 had massively high loss rates (Epoch 2/10 had about 34200) and disastrous correlation on the 1st jet plot. I imagine that making the learning rate smaller would give better results, but take very long.
# - Batch Size: Resetting learning rate and changing the batch size from 16 to 8 increased the computation time and also had pretty bad loss (although, this could be from the aftermath of the learning rate).
#
# **How well does the input compare with the predictions?**
#
# With the given hyperparameters, very well! There is a peak in the input at ~0 GeV that is unanticipated, but beyond that, there is high correlation - is there a way to statistically back this up?
#
# **What is overtraining and how can you combat it?**
#
# Overtraining is when the network becomes too accustomed to the data set and bases its actions on the specifics of the set, rather on the general traits that would allow it to make predictions. ([Source](https://www.allaboutcircuits.com/technical-articles/understanding-simple-neural-network-training-and-learning/#:~:text=Neural%20networks%20can%20respond%20to%20extremely%20complex%20relationships,classification%20task.%20This%20is%20called%20overtraining%20%28or%20overfitting%29.))
#
# **Can you plot eta and phi input vs predictions too?**
#
# Attempted below!
#
# **Can you add in electrons and muons into the training too? Do the predictions improve or get worse?**
#
# One way to find out!

# %%
# Struggled to figure out where pt, eta, and phi were in the reshaped data. Assumed:
# pt: [:,0,0], [:,0,1], [:,0,2], [:,1,0]
# eta: [:,1,1], [:,1,2], [:,2,0], [:,2,1]
# phi: [:,2,2], [:,3,0], [:,3,1], [:,3,2]

# Predictions didn't match except for pt, but max and medians were about right

# %%
# Eta input vs. predictions
decoded_data = output.reshape(output.shape[0], 4,3)
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,3)

print(decoded_data.shape,data_test.shape, data_valid.shape)

# Prediction isn't great - either model isn't trained well or I am calling the wrong output data
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,2,1],decoded_data[:,2,1]],bins=30,histtype='step',range = (-5,5), label = ['Input','Prediction'])
plt.xlabel(r"eta")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')
# Out:
# (107889, 4, 3) (107889, 12) (107889, 12)
# Text(0.5, 1.0, '1st Jet')

# %%
# phi input vs. predictions
decoded_data = output.reshape(output.shape[0], 4,3)
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,3)

print(decoded_data.shape,data_test.shape, data_valid.shape)

# Same thing. [:,0,2] = phi?
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,3,2],decoded_data[:,3,2]],bins=30,histtype='step',range = (-4,4), label = ['Input','Prediction'])
plt.xlabel(r"phi")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')
# Out:
# (107889, 4, 3) (107889, 12) (107889, 12)
# Text(0.5, 1.0, '1st Jet')

# %% [markdown]
# **Training model with electrons and muons now!** --> actually just muons rn bc I don't know what electrons to use

# %%
#Opening file
filename = "/uscms/home/jpearkes/eos/forAda/scouting_nano.root" # originally from root://hip-cms-se.csc.fi//store/user/pinkaew/scouting_nano_prod_golden/ScoutingPFRun3/crab_ScoutingPFRun3_Run2024D-v1_380385-380470_Golden/240517_205837/0000/scouting_nano_399.root
file = uproot.open(filename)

#Calling files
jet_pt = file["Events"]["L1Jet_pt"].array()
jet_eta = file["Events"]["L1Jet_eta"].array()
jet_phi = file["Events"]["L1Jet_phi"].array()
muon_pt = file["Events"]["L1Mu_pt"].array()
muon_eta = file["Events"]["L1Mu_eta"].array()
muon_phi = file["Events"]["L1Mu_phi"].array()

# %%
jet_pt = np.asarray(ak.fill_none(ak.pad_none(jet_pt, 4, clip=True), 0.0)) #replace missing values with none, increase value to target length with ak.pad_none
jet_eta = np.asarray(ak.fill_none(ak.pad_none(jet_eta, 4, clip=True), 0.0))
jet_phi = np.asarray(ak.fill_none(ak.pad_none(jet_phi, 4, clip=True), 0.0))
muon_pt = np.asarray(ak.fill_none(ak.pad_none(muon_pt, 4, clip=True), 0.0)) 
muon_eta = np.asarray(ak.fill_none(ak.pad_none(muon_eta, 4, clip=True), 0.0))
muon_phi = np.asarray(ak.fill_none(ak.pad_none(muon_phi, 4, clip=True), 0.0))

# %%
dataset = np.hstack([jet_pt,jet_eta,jet_phi,muon_pt,muon_eta,muon_phi]) #puts all the arrays next to eachother

dataset_size = dataset.shape[0] #gives you number of rows
data_train = dataset[0:int(dataset_size/2)] #50%
data_valid = dataset[int(dataset_size/2):int(dataset_size/4*3)] # 25% - used for tuning hyper-parameters
data_test = dataset[int(dataset_size/4*3):] # 25% - hold out for now

print(data_train.shape,data_test.shape, data_valid.shape)
# Out:
# (215777, 24) (107889, 24) (107889, 24)

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        print(batch)
        dim = tf.shape(z_mean)[1]
        print(dim)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
#Encoder

latent_dim = 4

encoder_inputs = keras.Input(shape=(24))
x = layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = False)(encoder_inputs)
x1 = layers.Dense(32, activation="relu")(x)
x2 = layers.Dense(16, activation="relu")(x1)
x3 = layers.Dense(8, activation="relu")(x2)
z_mean = layers.Dense(latent_dim, name="z_mean")(x3)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x3)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Decoder

latent_inputs = keras.Input(shape=(latent_dim,))
x4 = layers.Dense(16, activation="relu")(latent_inputs)
norm_layer_1 = layers.BatchNormalization(name="norm_1")(x4)
x5 = layers.Dense(32, activation="relu")(norm_layer_1)
norm_layer_2 = layers.BatchNormalization(name="norm_2")(x5)
x6 = layers.Dense(64, activation="relu")(norm_layer_2)
norm_layer_3 = layers.BatchNormalization(name="norm_3")(x6)
x7 = layers.Dense(128, activation="relu")(norm_layer_3)
x8 = layers.Dense(24,kernel_initializer='zeros', activation='linear')(x7)
decoder_outputs = tf.keras.layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = True)(x8)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

#Build Model

class VAE(keras.Model):
    def __init__(self, encoder, decoder,alpha = 1, beta = 0.001, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
        self.reco_scale = alpha * (1 - beta)
        self.kl_scale = beta
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.total_val_loss_tracker = keras.metrics.Mean(name="total_val_loss")
        self.reconstruction_val_loss_tracker = keras.metrics.Mean(name="val_reco_loss")
        self.kl_val_loss_tracker = keras.metrics.Mean(name="val_kl_loss")


    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    

    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            #MSE = keras.losses.MeanSquaredLogarithmicError(reduction="auto", name="mean_squared_error")
            #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
            MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
            reconstruction_loss = self.reco_scale * tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        
        grads = tape.gradient(total_loss, self.trainable_weights)

        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        
        #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
        MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
        reconstruction_loss = self.reco_scale* tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
                    
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        
        total_loss = reconstruction_loss + kl_loss
        
        self.total_val_loss_tracker.update_state(total_loss)
        self.reconstruction_val_loss_tracker.update_state(reconstruction_loss)
        self.kl_val_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_val_loss_tracker.result(),
            "reco_loss": self.reconstruction_val_loss_tracker.result(),
            "kl_loss": self.kl_val_loss_tracker.result()

      }
# Out:
# Tensor("sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_10 (InputLayer)          [(None, 24)]         0           []
#
#  normalization_9 (Normalization  (None, 24)          0           ['input_10[0][0]']
#  )
#
#  dense_24 (Dense)               (None, 32)           800         ['normalization_9[0][0]']
#
#  dense_25 (Dense)               (None, 16)           528         ['dense_24[0][0]']
#
#  dense_26 (Dense)               (None, 8)            136         ['dense_25[0][0]']
#
#  z_mean (Dense)                 (None, 4)            36          ['dense_26[0][0]']
#
#  z_log_var (Dense)              (None, 4)            36          ['dense_26[0][0]']
#
#  sampling_3 (Sampling)          (None, 4)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 1,536
# Trainable params: 1,536
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_11 (InputLayer)       [(None, 4)]               0
#
#  dense_27 (Dense)            (None, 16)                80
#
#  norm_1 (BatchNormalization)  (None, 16)               64
#
#  dense_28 (Dense)            (None, 32)                544
#
#  norm_2 (BatchNormalization)  (None, 32)               128
#
#  dense_29 (Dense)            (None, 64)                2112
#
#  norm_3 (BatchNormalization)  (None, 64)               256
#
#  dense_30 (Dense)            (None, 128)               8320
#
#  dense_31 (Dense)            (None, 24)                3096
#
#  normalization_10 (Normaliza  (None, 24)               0
#  tion)
#
# =================================================================
# Total params: 14,600
# Trainable params: 14,376
# Non-trainable params: 224
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0, patience=5, verbose = 1,restore_best_weights=True)
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0001,clipnorm=10.0))
history = vae.fit(data_train, validation_data = (data_valid, data_valid), epochs=15, batch_size=16, callbacks = [callback],shuffle=False)
# Out:
# Epoch 1/15
# Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# 13476/13487 [============================>.] - ETA: 0s - loss: 88.1338 - reconstruction_loss: 85.5470 - kl_loss: 0.3497Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# 13487/13487 [==============================] - 31s 2ms/step - loss: 88.1318 - reconstruction_loss: 85.5238 - kl_loss: 0.3496 - val_loss: 89.5961 - val_reco_loss: 89.2546 - val_kl_loss: 0.3416
# Epoch 2/15
# 13487/13487 [==============================] - 28s 2ms/step - loss: 85.4123 - reconstruction_loss: 83.1449 - kl_loss: 0.3313 - val_loss: 87.5421 - val_reco_loss: 87.2085 - val_kl_loss: 0.3336
# Epoch 3/15
# 13487/13487 [==============================] - 27s 2ms/step - loss: 83.5295 - reconstruction_loss: 81.1095 - kl_loss: 0.3164 - val_loss: 86.0150 - val_reco_loss: 85.6887 - val_kl_loss: 0.3259
# Epoch 4/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 81.9008 - reconstruction_loss: 79.5193 - kl_loss: 0.3042 - val_loss: 84.9624 - val_reco_loss: 84.6424 - val_kl_loss: 0.3195
# Epoch 5/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 80.9352 - reconstruction_loss: 78.3557 - kl_loss: 0.2944 - val_loss: 83.9568 - val_reco_loss: 83.6430 - val_kl_loss: 0.3137
# Epoch 6/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 80.5636 - reconstruction_loss: 77.6044 - kl_loss: 0.2830 - val_loss: 82.9569 - val_reco_loss: 82.6492 - val_kl_loss: 0.3076
# Epoch 7/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 80.0537 - reconstruction_loss: 76.6592 - kl_loss: 0.2683 - val_loss: 82.0086 - val_reco_loss: 81.7076 - val_kl_loss: 0.3012
# Epoch 8/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 79.7970 - reconstruction_loss: 75.8886 - kl_loss: 0.2586 - val_loss: 81.1091 - val_reco_loss: 80.8141 - val_kl_loss: 0.2954
# Epoch 9/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 78.8756 - reconstruction_loss: 74.9696 - kl_loss: 0.2525 - val_loss: 80.2522 - val_reco_loss: 79.9627 - val_kl_loss: 0.2902
# Epoch 10/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 78.3998 - reconstruction_loss: 74.2648 - kl_loss: 0.2466 - val_loss: 79.6633 - val_reco_loss: 79.3782 - val_kl_loss: 0.2854
# Epoch 11/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 77.3662 - reconstruction_loss: 73.4812 - kl_loss: 0.2396 - val_loss: 79.0742 - val_reco_loss: 78.7935 - val_kl_loss: 0.2809
# Epoch 12/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 77.6586 - reconstruction_loss: 73.2694 - kl_loss: 0.2338 - val_loss: 78.4674 - val_reco_loss: 78.1910 - val_kl_loss: 0.2767
# Epoch 13/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 76.1748 - reconstruction_loss: 72.1575 - kl_loss: 0.2267 - val_loss: 77.8634 - val_reco_loss: 77.5915 - val_kl_loss: 0.2725
# Epoch 14/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 76.1931 - reconstruction_loss: 71.9981 - kl_loss: 0.2202 - val_loss: 77.3278 - val_reco_loss: 77.0600 - val_kl_loss: 0.2685
# Epoch 15/15
# 13487/13487 [==============================] - 25s 2ms/step - loss: 75.3844 - reconstruction_loss: 71.2266 - kl_loss: 0.2138 - val_loss: 76.8322 - val_reco_loss: 76.5684 - val_kl_loss: 0.2645

# %%
z_mean, z_log_var, z = vae.encoder.predict(data_valid)
output = vae.decoder.predict(z)
# Out:
# 3372/3372 [==============================] - 3s 753us/step
# 3372/3372 [==============================] - 2s 715us/step

# %%
print(history.history.keys())

plt.plot(history.history['loss'],label="train")
plt.plot(history.history['val_loss'],label="validation")
#plt.yscale('log')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend( loc='upper right',frameon = False)
plt.show()

#This is more the model loss graph I expected above
# Out:
# dict_keys(['loss', 'reconstruction_loss', 'kl_loss', 'val_loss', 'val_reco_loss', 'val_kl_loss'])

# %%
# Need to reshape data slightly differently
decoded_data = output.reshape(output.shape[0], 4,6)
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,6)

print(decoded_data.shape,data_test.shape, data_valid.shape)

#Jet Pt plot
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,0,0],decoded_data[:,0,0]],bins=100,histtype='step',range = (0,100), label = ['Input','Prediction'])
plt.xlabel(r"$p_T$ [GeV]")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')

# Def worse than before! Is the network confusing what applies to jets vs muons?
# Out:
# (107889, 4, 6) (107889, 24) (107889, 24)
# Text(0.5, 1.0, '1st Jet')

# %% [markdown]
# ## Normalization layer axis = 1
# I didn't change the axis=0 --> axis=1 and delete the axis=-1* in the encoder and decoder lines, because this gave me an error in the shape compatibility. Instead, I changed the axis=-1 to axis=1 in the normalization line. This computes 12 mean values and variance values for the last axis. When it was set at axis=-1, "the last axis of the input is assumed to be a feature dimension and is normalized per index" [Source](https://keras.io/api/layers/preprocessing_layers/numerical/normalization/). It ran a lot faster, but the accuracy was not as good.
#
# *Wouldn't work anyway, because it defaults to axis=-1

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        print(batch)
        dim = tf.shape(z_mean)[1]
        print(dim)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
#Encoder

latent_dim = 4

encoder_inputs = keras.Input(shape=(12))
#Change axis = 1 and get rid of axis = -1
x = layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=1, invert = False)(encoder_inputs)
x1 = layers.Dense(32, activation="relu")(x)
x2 = layers.Dense(16, activation="relu")(x1)
x3 = layers.Dense(8, activation="relu")(x2)
z_mean = layers.Dense(latent_dim, name="z_mean")(x3)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x3)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Decoder

latent_inputs = keras.Input(shape=(latent_dim,))
x4 = layers.Dense(16, activation="relu")(latent_inputs)
norm_layer_1 = layers.BatchNormalization(name="norm_1")(x4)
x5 = layers.Dense(32, activation="relu")(norm_layer_1)
norm_layer_2 = layers.BatchNormalization(name="norm_2")(x5)
x6 = layers.Dense(64, activation="relu")(norm_layer_2)
norm_layer_3 = layers.BatchNormalization(name="norm_3")(x6)
x7 = layers.Dense(128, activation="relu")(norm_layer_3)
x8 = layers.Dense(12,kernel_initializer='zeros', activation='linear')(x7)
decoder_outputs = tf.keras.layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=1, invert = True)(x8)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

#Build Model

class VAE(keras.Model):
    def __init__(self, encoder, decoder,alpha = 1, beta = 0.001, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
        self.reco_scale = alpha * (1 - beta)
        self.kl_scale = beta
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.total_val_loss_tracker = keras.metrics.Mean(name="total_val_loss")
        self.reconstruction_val_loss_tracker = keras.metrics.Mean(name="val_reco_loss")
        self.kl_val_loss_tracker = keras.metrics.Mean(name="val_kl_loss")


    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    

    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            #MSE = keras.losses.MeanSquaredLogarithmicError(reduction="auto", name="mean_squared_error")
            #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
            MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
            reconstruction_loss = self.reco_scale * tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        
        grads = tape.gradient(total_loss, self.trainable_weights)

        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        
        #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
        MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
        reconstruction_loss = self.reco_scale* tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
                    
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        
        total_loss = reconstruction_loss + kl_loss
        
        self.total_val_loss_tracker.update_state(total_loss)
        self.reconstruction_val_loss_tracker.update_state(reconstruction_loss)
        self.kl_val_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_val_loss_tracker.result(),
            "reco_loss": self.reconstruction_val_loss_tracker.result(),
            "kl_loss": self.kl_val_loss_tracker.result()

      }

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0, patience=5, verbose = 1,restore_best_weights=True)
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0001,clipnorm=10.0))
history = vae.fit(data_train, validation_data = (data_valid, data_valid), epochs=10, batch_size=16, callbacks = [callback],shuffle=False)
# Out:
# Epoch 1/10
# Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# 13454/13487 [============================>.] - ETA: 0s - loss: 18659511728.1238 - reconstruction_loss: 7706777600.0000 - kl_loss: 136569.3750Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# 13487/13487 [==============================] - 27s 2ms/step - loss: 18631877684.3109 - reconstruction_loss: 7687920640.0000 - kl_loss: 136235.2031 - val_loss: 256.4217 - val_reco_loss: 255.9768 - val_kl_loss: 0.4452
# Epoch 2/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 174.4108 - reconstruction_loss: 133.6534 - kl_loss: 0.4555 - val_loss: 173.4610 - val_reco_loss: 173.0089 - val_kl_loss: 0.4514
# Epoch 3/10
# 13487/13487 [==============================] - 25s 2ms/step - loss: 92.6850 - reconstruction_loss: 78.6408 - kl_loss: 0.4764 - val_loss: 137.4498 - val_reco_loss: 136.9876 - val_kl_loss: 0.4619
# Epoch 4/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 66.2311 - reconstruction_loss: 59.0012 - kl_loss: 0.4706 - val_loss: 116.1318 - val_reco_loss: 115.6698 - val_kl_loss: 0.4616
# Epoch 5/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 47.1736 - reconstruction_loss: 45.0558 - kl_loss: 0.4330 - val_loss: 101.5427 - val_reco_loss: 101.0905 - val_kl_loss: 0.4518
# Epoch 6/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 39.0155 - reconstruction_loss: 39.5541 - kl_loss: 0.3942 - val_loss: 91.5238 - val_reco_loss: 91.0860 - val_kl_loss: 0.4378
# Epoch 7/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 37.3242 - reconstruction_loss: 37.8641 - kl_loss: 0.3552 - val_loss: 84.1478 - val_reco_loss: 83.7244 - val_kl_loss: 0.4236
# Epoch 8/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 36.4464 - reconstruction_loss: 36.9573 - kl_loss: 0.3252 - val_loss: 78.4391 - val_reco_loss: 78.0296 - val_kl_loss: 0.4095
# Epoch 9/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 35.5386 - reconstruction_loss: 35.9280 - kl_loss: 0.3054 - val_loss: 73.9919 - val_reco_loss: 73.5946 - val_kl_loss: 0.3970
# Epoch 10/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 34.8659 - reconstruction_loss: 35.6705 - kl_loss: 0.2883 - val_loss: 70.5956 - val_reco_loss: 70.2101 - val_kl_loss: 0.3854

# %%
z_mean, z_log_var, z = vae.encoder.predict(data_valid)
output = vae.decoder.predict(z)
# Out:
# Tensor("encoder/sampling_3/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_3/strided_slice_1:0", shape=(), dtype=int32)
# 3372/3372 [==============================] - 3s 762us/step
# 3372/3372 [==============================] - 2s 701us/step

# %%
plt.plot(history.history['loss'],label="train")
plt.plot(history.history['val_loss'],label="validation")
plt.title('model loss')
plt.yscale('log')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend( loc='upper right',frameon = False)
plt.show()

# %%
decoded_data = output.reshape(output.shape[0], 4,3) # Do the three dimensions correspond to the three variables? Bc I feel like no
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,3)

print(decoded_data.shape,data_test.shape, data_valid.shape)

#Jet Pt plot
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,0,0],decoded_data[:,0,0]],bins=100,histtype='step',range = (0,100), label = ['Input','Prediction'])
plt.xlabel(r"$p_T$ [GeV]")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')
# Out:
# (107889, 4, 3) (107889, 12) (107889, 12)
# Text(0.5, 1.0, '1st Jet')

# %% [markdown]
# ## Patience, learning rate, and the size of the neural network
# **Patience**
# - Small value: Put patience at 1 and ran it for 50 epochs and it still didn't stop! Better loss curve and good fit between prediction and data. In theory, a low patience value stops once there's no sign of improvement.
# - Large value: A high patience value means that it will run through a higher number of epochs, even if it's not improving. This can lead to overtraining.
#
# **Learning rate**
# - Small value: Set to 0.000001, stopped after 6 epochs with a patience of 5. Validation loss started to increase, which is a sign of overfitting.
# - Large value: Set at 0.1. Stopped after 5 epochs with a patience of 5, couldn't produce loss or prediction graphs.
#
# **Size of NN**
# - Small value: Removed x2 and x3 in encoder and x6 and x7 in decoder. Poorer correlation, but not as bad as I would've assumed.
# - Large value: Added 2 encoding layers and 1 decoding layer, seen below. Predictions improved, although loss curve still looks a little strange (likely would improve with > 20 epochs).

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        print(batch)
        dim = tf.shape(z_mean)[1]
        print(dim)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
#Encoder

latent_dim = 4

encoder_inputs = keras.Input(shape=(12))
x = layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = False)(encoder_inputs)
xa = layers.Dense(128, activation="relu")(x)
xb = layers.Dense(64, activation="relu")(xa)
x1 = layers.Dense(32, activation="relu")(xb)
x2 = layers.Dense(16, activation="relu")(x1)
x3 = layers.Dense(8, activation="relu")(x2)
z_mean = layers.Dense(latent_dim, name="z_mean")(x1)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x1)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Decoder

latent_inputs = keras.Input(shape=(latent_dim,))
x4 = layers.Dense(16, activation="relu")(latent_inputs)
norm_layer_1 = layers.BatchNormalization(name="norm_1")(x4)
x5 = layers.Dense(32, activation="relu")(norm_layer_1)
norm_layer_2 = layers.BatchNormalization(name="norm_2")(x5)
x6 = layers.Dense(64, activation="relu")(norm_layer_2)
norm_layer_3 = layers.BatchNormalization(name="norm_3")(x6)
x7 = layers.Dense(128, activation="relu")(norm_layer_3)
norm_layer_4 = layers.BatchNormalization(name="norm_4")(x7)
x7a = layers.Dense(256, activation="relu")(norm_layer_4)
x8 = layers.Dense(12,kernel_initializer='zeros', activation='linear')(x5)
decoder_outputs = tf.keras.layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = True)(x8)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

#Build Model

class VAE(keras.Model):
    def __init__(self, encoder, decoder,alpha = 1, beta = 0.001, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
        self.reco_scale = alpha * (1 - beta)
        self.kl_scale = beta
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.total_val_loss_tracker = keras.metrics.Mean(name="total_val_loss")
        self.reconstruction_val_loss_tracker = keras.metrics.Mean(name="val_reco_loss")
        self.kl_val_loss_tracker = keras.metrics.Mean(name="val_kl_loss")


    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    

    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            #MSE = keras.losses.MeanSquaredLogarithmicError(reduction="auto", name="mean_squared_error")
            #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
            MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
            reconstruction_loss = self.reco_scale * tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
            
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        
        grads = tape.gradient(total_loss, self.trainable_weights)

        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        
        #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
        MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
        reconstruction_loss = self.reco_scale* tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
                    
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        
        total_loss = reconstruction_loss + kl_loss
        
        self.total_val_loss_tracker.update_state(total_loss)
        self.reconstruction_val_loss_tracker.update_state(reconstruction_loss)
        self.kl_val_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_val_loss_tracker.result(),
            "reco_loss": self.reconstruction_val_loss_tracker.result(),
            "kl_loss": self.kl_val_loss_tracker.result()

      }

callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0, patience=5, verbose = 1,restore_best_weights=True)
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0001,clipnorm=10.0))
history = vae.fit(data_train, validation_data = (data_valid, data_valid), epochs=20, batch_size=16, callbacks = [callback],shuffle=False)
# Out:
# Tensor("sampling_17/strided_slice:0", shape=(), dtype=int32)
# Tensor("sampling_17/strided_slice_1:0", shape=(), dtype=int32)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_40 (InputLayer)          [(None, 12)]         0           []
#
#  normalization_38 (Normalizatio  (None, 12)          0           ['input_40[0][0]']
#  n)
#
#  dense_133 (Dense)              (None, 128)          1664        ['normalization_38[0][0]']
#
#  dense_134 (Dense)              (None, 64)           8256        ['dense_133[0][0]']
#
#  dense_135 (Dense)              (None, 32)           2080        ['dense_134[0][0]']
#
#  z_mean (Dense)                 (None, 4)            132         ['dense_135[0][0]']
#
#  z_log_var (Dense)              (None, 4)            132         ['dense_135[0][0]']
#
#  sampling_17 (Sampling)         (None, 4)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 12,264
# Trainable params: 12,264
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_41 (InputLayer)       [(None, 4)]               0
#
#  dense_138 (Dense)           (None, 16)                80
#
#  norm_1 (BatchNormalization)  (None, 16)               64
#
#  dense_139 (Dense)           (None, 32)                544
#
#  dense_143 (Dense)           (None, 12)                396
#
#  normalization_39 (Normaliza  (None, 12)               0
#  tion)
#
# =================================================================
# Total params: 1,084
# Trainable params: 1,052
# Non-trainable params: 32
# _________________________________________________________________
# Epoch 1/20
# Tensor("encoder/sampling_17/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_17/strided_slice_1:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_17/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_17/strided_slice_1:0", shape=(), dtype=int32)
# 13472/13487 [============================>.] - ETA: 0s - loss: 2466061303837578389403234992128.0000 - reconstruction_loss: 958172088383164761403736195072.0000 - kl_loss: 83085457570603023979123834880.0000Tensor("encoder/sampling_17/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_17/strided_slice_1:0", shape=(), dtype=int32)
# 13487/13487 [==============================] - 23s 2ms/step - loss: 2464370372196269971064194334720.0000 - reconstruction_loss: 957106420273174465786232700928.0000 - kl_loss: 82993050303266230761582231552.0000 - val_loss: 83.6645 - val_reco_loss: 78.1511 - val_kl_loss: 5.5134
# Epoch 2/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 76.0872 - reconstruction_loss: 54.5626 - kl_loss: 4.2649 - val_loss: 63.9826 - val_reco_loss: 59.4480 - val_kl_loss: 4.5348
# Epoch 3/20
# 13487/13487 [==============================] - 21s 2ms/step - loss: 42.2408 - reconstruction_loss: 37.1974 - kl_loss: 3.0370 - val_loss: 55.7768 - val_reco_loss: 51.8806 - val_kl_loss: 3.8964
# Epoch 4/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 37.5625 - reconstruction_loss: 34.6953 - kl_loss: 2.2939 - val_loss: 50.9177 - val_reco_loss: 47.4836 - val_kl_loss: 3.4342
# Epoch 5/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 35.6303 - reconstruction_loss: 33.6224 - kl_loss: 1.8330 - val_loss: 48.0702 - val_reco_loss: 44.9885 - val_kl_loss: 3.0818
# Epoch 6/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 34.5716 - reconstruction_loss: 33.0372 - kl_loss: 1.5353 - val_loss: 46.0010 - val_reco_loss: 43.1956 - val_kl_loss: 2.8055
# Epoch 7/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 34.0737 - reconstruction_loss: 32.7752 - kl_loss: 1.3479 - val_loss: 44.3747 - val_reco_loss: 41.7880 - val_kl_loss: 2.5869
# Epoch 8/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 33.6629 - reconstruction_loss: 32.5477 - kl_loss: 1.2044 - val_loss: 43.0496 - val_reco_loss: 40.6436 - val_kl_loss: 2.4064
# Epoch 9/20
# 13487/13487 [==============================] - 21s 2ms/step - loss: 33.4637 - reconstruction_loss: 32.4134 - kl_loss: 1.0898 - val_loss: 41.9770 - val_reco_loss: 39.7221 - val_kl_loss: 2.2549
# Epoch 10/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 33.1396 - reconstruction_loss: 32.2068 - kl_loss: 1.0094 - val_loss: 41.1953 - val_reco_loss: 39.0684 - val_kl_loss: 2.1268
# Epoch 11/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 33.0263 - reconstruction_loss: 32.1704 - kl_loss: 0.9442 - val_loss: 40.4492 - val_reco_loss: 38.4335 - val_kl_loss: 2.0159
# Epoch 12/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 32.8723 - reconstruction_loss: 32.0536 - kl_loss: 0.8808 - val_loss: 39.8021 - val_reco_loss: 37.8837 - val_kl_loss: 1.9187
# Epoch 13/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.7167 - reconstruction_loss: 31.9813 - kl_loss: 0.8177 - val_loss: 39.3090 - val_reco_loss: 37.4772 - val_kl_loss: 1.8322
# Epoch 14/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.5444 - reconstruction_loss: 31.8812 - kl_loss: 0.7706 - val_loss: 38.9089 - val_reco_loss: 37.1545 - val_kl_loss: 1.7547
# Epoch 15/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.4585 - reconstruction_loss: 31.8389 - kl_loss: 0.7241 - val_loss: 38.4827 - val_reco_loss: 36.7988 - val_kl_loss: 1.6842
# Epoch 16/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.3729 - reconstruction_loss: 31.7452 - kl_loss: 0.6773 - val_loss: 38.1142 - val_reco_loss: 36.4949 - val_kl_loss: 1.6197
# Epoch 17/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 32.2528 - reconstruction_loss: 31.6657 - kl_loss: 0.6410 - val_loss: 37.7534 - val_reco_loss: 36.1928 - val_kl_loss: 1.5608
# Epoch 18/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.2721 - reconstruction_loss: 31.6815 - kl_loss: 0.6162 - val_loss: 37.4550 - val_reco_loss: 35.9477 - val_kl_loss: 1.5075
# Epoch 19/20
# 13487/13487 [==============================] - 20s 1ms/step - loss: 32.1802 - reconstruction_loss: 31.6094 - kl_loss: 0.5913 - val_loss: 37.1618 - val_reco_loss: 35.7039 - val_kl_loss: 1.4581
# Epoch 20/20
# 13487/13487 [==============================] - 20s 2ms/step - loss: 32.0830 - reconstruction_loss: 31.5312 - kl_loss: 0.5582 - val_loss: 36.8994 - val_reco_loss: 35.4875 - val_kl_loss: 1.4121

# %%
z_mean, z_log_var, z = vae.encoder.predict(data_valid)
output = vae.decoder.predict(z)
# Out:
# Tensor("encoder/sampling_17/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_17/strided_slice_1:0", shape=(), dtype=int32)
# 3372/3372 [==============================] - 3s 728us/step
# 3372/3372 [==============================] - 2s 610us/step

# %%
plt.plot(history.history['loss'],label="train")
plt.plot(history.history['val_loss'],label="validation")
plt.title('model loss')
plt.yscale('log')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend( loc='upper right',frameon = False)
plt.show()

decoded_data = output.reshape(output.shape[0], 4,3) # Do the three dimensions correspond to the three variables? Bc I feel like no
data_valid_reshaped = data_valid.reshape(data_valid.shape[0], 4,3)

#print(decoded_data.shape,data_test.shape, data_valid.shape)

#Jet Pt plot
plt.figure()
plt.rcParams['figure.dpi'] = 140
plt.hist([data_valid_reshaped[:,0,0],decoded_data[:,0,0]],bins=100,histtype='step',range = (0,100), label = ['Input','Prediction'])
plt.xlabel(r"$p_T$ [GeV]")
plt.ylabel("Events")
plt.legend(frameon = False)
plt.title('1st Jet')
# Out:
# Text(0.5, 1.0, '1st Jet')

# %% [markdown]
# ## 2D Histograms of Loss vs. Objects
# Pranked I am copying and pasting again because I think I have to change something in the model definition?

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        print(batch)
        dim = tf.shape(z_mean)[1]
        print(dim)
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon
    
#Encoder

latent_dim = 4

encoder_inputs = keras.Input(shape=(12))
x = layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = False)(encoder_inputs)
x1 = layers.Dense(32, activation="relu")(x)
x2 = layers.Dense(16, activation="relu")(x1)
x3 = layers.Dense(8, activation="relu")(x2)
z_mean = layers.Dense(latent_dim, name="z_mean")(x3)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x3)
z = Sampling()([z_mean, z_log_var])
encoder = keras.Model(encoder_inputs, [z_mean, z_log_var, z], name="encoder")
encoder.summary()

#Decoder

latent_inputs = keras.Input(shape=(latent_dim,))
x4 = layers.Dense(16, activation="relu")(latent_inputs)
norm_layer_1 = layers.BatchNormalization(name="norm_1")(x4)
x5 = layers.Dense(32, activation="relu")(norm_layer_1)
norm_layer_2 = layers.BatchNormalization(name="norm_2")(x5)
x6 = layers.Dense(64, activation="relu")(norm_layer_2)
norm_layer_3 = layers.BatchNormalization(name="norm_3")(x6)
x7 = layers.Dense(128, activation="relu")(norm_layer_3)
x8 = layers.Dense(12,kernel_initializer='zeros', activation='linear')(x7)
decoder_outputs = tf.keras.layers.Normalization(mean=np.mean(data_train,axis=0),variance=np.std(data_train,axis=0), axis=-1, invert = True)(x8)

decoder = keras.Model(latent_inputs, decoder_outputs, name="decoder")
decoder.summary()

#Build Model

class VAE(keras.Model):
    def __init__(self, encoder, decoder,alpha = 1, beta = 0.001, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        
        self.reco_scale = alpha * (1 - beta)
        self.kl_scale = beta
        
        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = keras.metrics.Mean(name="kl_loss")
        self.total_val_loss_tracker = keras.metrics.Mean(name="total_val_loss")
        self.reconstruction_val_loss_tracker = keras.metrics.Mean(name="val_reco_loss")
        self.kl_val_loss_tracker = keras.metrics.Mean(name="val_kl_loss")
        # Is this block the issue? Because it gets the mean, not every little thing? 

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]
    

    
    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            
            #MSE = keras.losses.MeanSquaredLogarithmicError(reduction="auto", name="mean_squared_error")
            #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
            MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
            reconstruction_loss = self.reco_scale * tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))

            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        
        grads = tape.gradient(total_loss, self.trainable_weights)

        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)


        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }
    
    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
            
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        
        #MSE = keras.losses.MeanSquaredError(reduction="auto", name="mean_squared_error")
        MSE = keras.losses.MeanSquaredError(reduction="none", name="mean_squared_error")
        reconstruction_loss = self.reco_scale* tf.reduce_mean(tf.reduce_sum(MSE(data,reconstruction)))
        r_loss = MSE(data,reconstruction)
   #     reconstruction_loss = self.reco_scale * tf.reduce_mean(MSE(data, reconstruction), axis=0) --> my line 
            
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = self.kl_scale * tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        
        total_loss = reconstruction_loss + kl_loss
   #     total_loss = tf.reduce_mean(reconstruction_loss) + kl_loss --> my line
        
        self.total_val_loss_tracker.update_state(total_loss)
        self.reconstruction_val_loss_tracker.update_state(reconstruction_loss)
        self.kl_val_loss_tracker.update_state(kl_loss)

        return {
            "indiv_reco_loss" : r_loss,
            "loss": self.total_val_loss_tracker.result(),
            "reco_loss": self.reconstruction_val_loss_tracker.result(),
            "kl_loss": self.kl_val_loss_tracker.result()

      }
# Out:
# Tensor("sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 12)]         0           []
#
#  normalization_4 (Normalization  (None, 12)          0           ['input_5[0][0]']
#  )
#
#  dense_16 (Dense)               (None, 32)           416         ['normalization_4[0][0]']
#
#  dense_17 (Dense)               (None, 16)           528         ['dense_16[0][0]']
#
#  dense_18 (Dense)               (None, 8)            136         ['dense_17[0][0]']
#
#  z_mean (Dense)                 (None, 4)            36          ['dense_18[0][0]']
#
#  z_log_var (Dense)              (None, 4)            36          ['dense_18[0][0]']
#
#  sampling_2 (Sampling)          (None, 4)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 1,152
# Trainable params: 1,152
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 4)]               0
#
#  dense_19 (Dense)            (None, 16)                80
#
#  norm_1 (BatchNormalization)  (None, 16)               64
#
#  dense_20 (Dense)            (None, 32)                544
#
#  norm_2 (BatchNormalization)  (None, 32)               128
#
#  dense_21 (Dense)            (None, 64)                2112
#
#  norm_3 (BatchNormalization)  (None, 64)               256
#
#  dense_22 (Dense)            (None, 128)               8320
#
#  dense_23 (Dense)            (None, 12)                1548
#
#  normalization_5 (Normalizat  (None, 12)               0
#  ion)
#
# =================================================================
# Total params: 13,052
# Trainable params: 12,828
# Non-trainable params: 224
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0, patience=5, verbose = 1,restore_best_weights=True)
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate = 0.0001,clipnorm=10.0))
history = vae.fit(data_train, validation_data = (data_valid, data_valid), epochs=10, batch_size=16, callbacks = [callback],shuffle=False)
# Out:
# Epoch 1/10
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 13464/13487 [============================>.] - ETA: 0s - loss: 11585.3802 - reconstruction_loss: 4135.5483 - kl_loss: 1.2650Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 13487/13487 [==============================] - 29s 2ms/step - loss: 11572.1199 - reconstruction_loss: 4128.6499 - kl_loss: 1.2636 - val_indiv_reco_loss: 1.0497 - val_loss: 110.1722 - val_reco_loss: 109.6403 - val_kl_loss: 0.5317
# Epoch 2/10
# 13487/13487 [==============================] - 25s 2ms/step - loss: 97.9661 - reconstruction_loss: 79.3419 - kl_loss: 0.6019 - val_indiv_reco_loss: 0.7267 - val_loss: 83.9535 - val_reco_loss: 83.3625 - val_kl_loss: 0.5911
# Epoch 3/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 56.2100 - reconstruction_loss: 50.9229 - kl_loss: 0.6720 - val_indiv_reco_loss: 0.7310 - val_loss: 72.2908 - val_reco_loss: 71.6750 - val_kl_loss: 0.6163
# Epoch 4/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 46.4638 - reconstruction_loss: 43.7483 - kl_loss: 0.6681 - val_indiv_reco_loss: 0.6920 - val_loss: 65.6062 - val_reco_loss: 64.9812 - val_kl_loss: 0.6255
# Epoch 5/10
# 13487/13487 [==============================] - 24s 2ms/step - loss: 44.0197 - reconstruction_loss: 41.7742 - kl_loss: 0.6455 - val_indiv_reco_loss: 0.6615 - val_loss: 60.9286 - val_reco_loss: 60.3047 - val_kl_loss: 0.6244
# Epoch 6/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 42.5668 - reconstruction_loss: 40.4753 - kl_loss: 0.6028 - val_indiv_reco_loss: 0.6495 - val_loss: 58.2087 - val_reco_loss: 57.5924 - val_kl_loss: 0.6168
# Epoch 7/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 41.7464 - reconstruction_loss: 39.7150 - kl_loss: 0.5607 - val_indiv_reco_loss: 0.6856 - val_loss: 55.4865 - val_reco_loss: 54.8823 - val_kl_loss: 0.6046
# Epoch 8/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 41.5119 - reconstruction_loss: 39.5440 - kl_loss: 0.5150 - val_indiv_reco_loss: 0.6368 - val_loss: 53.0751 - val_reco_loss: 52.4850 - val_kl_loss: 0.5905
# Epoch 9/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 41.2137 - reconstruction_loss: 39.2356 - kl_loss: 0.4808 - val_indiv_reco_loss: 0.7141 - val_loss: 51.5259 - val_reco_loss: 50.9497 - val_kl_loss: 0.5767
# Epoch 10/10
# 13487/13487 [==============================] - 23s 2ms/step - loss: 41.1339 - reconstruction_loss: 39.1003 - kl_loss: 0.4539 - val_indiv_reco_loss: 0.6906 - val_loss: 50.0845 - val_reco_loss: 49.5223 - val_kl_loss: 0.5626

# %%
z_mean, z_log_var, z = vae.encoder.predict(data_valid)
output = vae.decoder.predict(z)
# Out:
# Tensor("encoder/sampling_2/strided_slice:0", shape=(), dtype=int32)
# Tensor("encoder/sampling_2/strided_slice_1:0", shape=(), dtype=int32)
# 3372/3372 [==============================] - 3s 926us/step
# 3372/3372 [==============================] - 3s 850us/step

# %%
a = vae.test_step(data_train[0])
# Out:
# tf.Tensor(1, shape=(), dtype=int32)
# tf.Tensor(4, shape=(), dtype=int32)

# %%
print(a["indiv_reco_less"].numpy())
# Out:
# 0.85979563

# %%
data_test[:,0]
# Out:
# array([ 23.5,  14. ,  20.5, ...,  28. , 214.5,  21.5])

# %%
# %%capture --no-display

t = []
length = data_test.shape[0]

for i in range(length):
    event = vae.test_step(data_train[i,0]) # Just for jet_pt
    rloss = event["indiv_reco_loss"].numpy() 
    t.append(rloss)

# %% [markdown]
# ## Feelings and Reflections
# My thought process was to add a step in the VAE to capture the reconstruction loss, hence the "indiv_reco_loss" in the output. I don't know if this was the actual value I was supposed to get. Instead of the MSE, I also tried to define this:
#
#     reconstruction_loss = self.reco_scale * tf.reduce_mean(MSE(data, reconstruction), axis=0)
#
# And compensate for it in the total loss. However, I don't think either of these were successful. To access them, I tried to run a for loop (directly above), which was obviously pretty slow. I have both arrays below, and have paused here to ask for help!

# %%
ak.flatten(t, axis=1)
# Out:
# <Array [353, 171, 267, 771, ..., 241, 241, 171, 241] type='49221 * float64'>

# %%
data_test[:49221, 0]
# Out:
# array([ 23.5,  14. ,  20.5, ..., 196. ,  26.5,  20. ])
